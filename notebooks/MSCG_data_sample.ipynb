# %%
import torch
import pandas as pd
import numpy as np

from collections import Counter

# %%
#file_path = "/scratch/c.scmag3/conceptEmbeddingModel/data/data-concept-instance-relations.txt" 
file_path = "./../../data/ms_concept_graph/data-concept-instance-relations.txt"
data_df = pd.read_csv(file_path, header=None, names=["property", "concept", "num_relation"], sep="\t")

# %%
print ('Data After Loading MS Concept Graph')
data_df
# Out:
# Data After Loading MS Concept Graph
#                                  property  \
# 0                                  factor
# 1                 free rich company datum
# 2                 free rich company datum
# 3                                   state
# 4                              supplement
# ...                                   ...
# 33377315   popular legacy datum structure
# 33377316                   norwegian food
# 33377317                     freeze skill
# 33377318  enhanced enforcement initiative
# 33377319  enhanced enforcement initiative
#
#                                              concept  num_relation
# 0                                                age         35167
# 1                                               size         33222
# 2                                            revenue         33185
# 3                                         california         18062
# 4                            msm glucosamine sulfate         15942
# ...                                              ...           ...
# 33377315                          binary search tree             1
# 33377316                                       lefse             1
# 33377317                                     new fot             1
# 33377318  monthly impact inspections of problem mine             1
# 33377319           pattern of violation notification             1
#
# [33377320 rows x 3 columns]

# %%
data_df.sort_values('num_relation', ascending=False, inplace=True)

# %%
print ('Data After Sorting on Num Relation')
data_df
# Out:
# Data After Sorting on Num Relation
#                                  property                            concept  \
# 0                                  factor                                age
# 1                 free rich company datum                               size
# 2                 free rich company datum                            revenue
# 3                                   state                         california
# 4                              supplement            msm glucosamine sulfate
# ...                                   ...                                ...
# 18841597        permanent control measure                       straw wattle
# 18841596        permanent control measure                          check dam
# 18841595        permanent control measure                  vegetative buffer
# 18841594        permanent control measure                       ditch lining
# 33377319  enhanced enforcement initiative  pattern of violation notification
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
data_df = data_df[['concept', 'property', 'num_relation']]
data_df
# Out:
#                                     concept                         property  \
# 0                                       age                           factor
# 1                                      size          free rich company datum
# 2                                   revenue          free rich company datum
# 3                                california                            state
# 4                   msm glucosamine sulfate                       supplement
# ...                                     ...                              ...
# 18841597                       straw wattle        permanent control measure
# 18841596                          check dam        permanent control measure
# 18841595                  vegetative buffer        permanent control measure
# 18841594                       ditch lining        permanent control measure
# 33377319  pattern of violation notification  enhanced enforcement initiative
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
top_k = 15000

# %%
data_df = data_df[0:top_k]
print (f'Data Df after taking top {top_k} records \n:')
data_df
# Out:
# Data Df after taking top 15000 records
# :
#                        concept                   property  num_relation
# 0                          age                     factor         35167
# 1                         size    free rich company datum         33222
# 2                      revenue    free rich company datum         33185
# 3                   california                      state         18062
# 4      msm glucosamine sulfate                 supplement         15942
# ...                        ...                        ...           ...
# 15045                  dentist        health professional           191
# 15044              temperature    meteorological variable           191
# 15043                  toluene  volatile organic compound           191
# 15042                 football          competitive sport           191
# 15041                 medicaid        entitlement program           191
#
# [15000 rows x 3 columns]

# %%
unique_concept_list = data_df["concept"].unique()
# np.random.shuffle(unique_concept_list)
print (unique_concept_list.shape[0])
print (type(unique_concept_list))
# Out:
# 6006
# <class 'numpy.ndarray'>

# %%
num_unique_concepts = len(unique_concept_list)
print ('Num Unique Positive Concepts:', num_unique_concepts)
# Out:
# Num Unique Positive Concepts: 6006

# %%
print (data_df["concept"].value_counts())
# Out:
# age                             71
# water                           52
# temperature                     52
# diabetes                        45
# education                       44
#                                 ..
# generalized anxiety disorder     1
# exxonmobil                       1
# genetic background               1
# family income                    1
# tree removal                     1
# Name: concept, Length: 6006, dtype: int64

# %%
train_ratio, val_ratio, test_ratio = 0.85, 0.10, 0.05

# %%
num_train_concepts = int(num_unique_concepts * train_ratio)
num_val_concepts = int(num_unique_concepts * val_ratio)
num_test_concepts = int(num_unique_concepts * test_ratio)

print (num_train_concepts)
print (num_val_concepts)
print (num_test_concepts)
# Out:
# 5105
# 600
# 300

# %%
train_concept = unique_concept_list[0:num_train_concepts]
valid_concept = unique_concept_list[num_train_concepts:num_train_concepts + num_val_concepts]
test_concept = unique_concept_list[num_train_concepts + num_val_concepts:]

print ('Number of Positive Train Concept :', len(train_concept))
print ('Number of Positive Valid Concept :', len(valid_concept))
print ('Number of Positive Test Concept :', len(test_concept))
# Out:
# Number of Positive Train Concept : 5105
# Number of Positive Valid Concept : 600
# Number of Positive Test Concept : 301

# %% [markdown]
# print ('\nTrain Concept :', *train_concept, sep=", ")
# print ('\nValid Concept :', *valid_concept, sep=", ")
# print ('\nTest Concept :', *test_concept, sep=", ")

# %%
print ('Total Number of Positive Concepts :', num_train_concepts + num_val_concepts + num_test_concepts)
# Out:
# Total Number of Positive Concepts : 6005

# %%
print ('+' * 50)

print ('Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap')
assert set (train_concept) != set (valid_concept)
assert set (train_concept) != set (test_concept)
assert set (valid_concept) != set (test_concept)

print ('Assertions Passed')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap
# Assertions Passed

# %%
train_df = data_df[data_df['concept'].isin(train_concept)]
valid_df = data_df[data_df['concept'].isin(valid_concept)]
test_df = data_df[data_df['concept'].isin(test_concept)]

print ('Number of Train Records :', len(train_df))
print ('Number of Valid Records :', len(valid_df))
print ('NUmber of Test Records :', len(test_df))

print ('+' * 50)
# Out:
# Number of Train Records : 14032
# Number of Valid Records : 661
# NUmber of Test Records : 307
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
print ('\ncheck if train, val and test dataframes have any overlap')
df = train_df.merge(test_df, how = 'inner' ,indicator=False)
print('\n', df)

df = train_df.merge(valid_df, how = 'inner' ,indicator=False)
print('\n', df)

df = test_df.merge(valid_df, how = 'inner', indicator=False)
print('\n', df)
# Out:
# check if train, val and test dataframes have any overlap
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []

# %%
train_df = train_df.drop("num_relation", axis=1)

# %%
train_df.to_csv("mscg_new_pos_train.tsv", sep="\t", index=None, header=None)

# %%
valid_df = valid_df.drop("num_relation", axis=1)

# %%
valid_df.to_csv("mscg_new_pos_valid.tsv", sep="\t", index=None, header=None)

# %%
def generate_pos_neg_test_data(test_df):
    
    # print (test_df.head())
    
    test_df.reset_index(drop=True, inplace=True)
    test_df = test_df.drop("num_relation", axis=1)
    test_df["label"] = 1
    
    test_df.set_index("concept", drop=False)
    
    print (test_df.head())
    print (test_df.shape)
    
    unique_test_concept = test_df["concept"].unique()
    
    print (len(unique_test_concept))
    
    negative_data = []
    for concept in unique_test_concept:
        
        temp_df = test_df[test_df["concept"] != concept]
        
        # print ("temp_df")
        # print (temp_df)
        
        sampled_property = np.random.choice(temp_df["property"].unique(), size=5, replace=False)
        
        # print ("sampled_property")
        # print (sampled_property)
        
        negative_data.append([(concept, prop, 0) for prop in sampled_property])
    
    
    # print ("negative_data")
    # print (len(negative_data))
    # print (negative_data)
    
    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)

    print("negative_data_df")
    print (negative_data_df.shape)
    
    all_data = pd.concat([test_df, negative_data_df], ignore_index=True)
    
    print("All Data")
    print (all_data.shape)
    
    all_data= all_data.sample(frac=1)
    
    all_data.to_csv("mscg_new_pos_neg_test.tsv", sep="\t", header=None, index=None)
    
    all_data.set_index("concept", drop=False)
    
    for concept in all_data["concept"].unique():
        print (all_data[all_data["concept"] == concept])
        print ()

    
generate_pos_neg_test_data(test_df)
# Out:
#        concept property  label
# 0     goldfish     fish      1
# 1        armor     item      1
# 2  forgiveness    topic      1
# 3        sound    topic      1
# 4   scheduling    issue      1
# (307, 3)
# 301
# negative_data_df
# (1505, 3)
# All Data
# (1812, 3)
#       concept             property  label
# 132  palm oil        vegetable oil      1
# 967  palm oil  antioxidizing agent      0
# 971  palm oil          alkyl group      0
# 970  palm oil       funding source      0
# 969  palm oil              journal      0
# 968  palm oil              service      0
#
#         concept            property  label
# 1325  dictation           pollutant      0
# 1323  dictation             keyword      0
# 203   dictation  musicianship skill      1
# 1322  dictation        light source      0
# 1326  dictation         soy product      0
# 1324  dictation       blood thinner      0
#
#      concept          property  label
# 1402  baboon              word      0
# 1405  baboon  optical property      0
# 219   baboon            animal      1
# 1404  baboon         parameter      0
# 1403  baboon    sleep disorder      0
# 1406  baboon              game      0
#
#      concept    property  label
# 1678    hela  amino acid      0
# 1681    hela   character      0
# 1680    hela     prophet      0
# 1679    hela  regulation      0
# 277     hela   cell line      1
# 1677    hela       nsaid      0
#
#                  concept       property  label
# 1711  salt concentration           game      0
# 1708  salt concentration  essential oil      0
# 284   salt concentration         factor      1
# 1710  salt concentration       cytokine      0
# 1709  salt concentration        emotion      0
# 1707  salt concentration   distribution      0
#
#              concept          property  label
# 248   healthy eating             topic      1
# 1541  healthy eating      health issue      0
# 1537  healthy eating            liquid      0
# 1540  healthy eating             organ      0
# 1538  healthy eating  operating system      0
# 1539  healthy eating              herb      0
#
#      concept            property  label
# 1176  garden  autoimmune disease      0
# 1172  garden              injury      0
# 1173  garden   patient care unit      0
# 173   garden                area      1
# 1174  garden           pollutant      0
# 1175  garden             amenity      0
#
#                  concept     property  label
# 1750  retirement account         herb      0
# 1747  retirement account      company      0
# 1748  retirement account  third party      0
# 1751  retirement account         film      0
# 293   retirement account        asset      1
# 1749  retirement account        nsaid      0
#
#           concept          property  label
# 917  windows 2000         stimulant      0
# 919  windows 2000           mineral      0
# 921  windows 2000            method      0
# 918  windows 2000           network      0
# 122  windows 2000  operating system      1
# 920  windows 2000            liquid      0
#
#         concept                      property  label
# 804  sound card                     incentive      0
# 806  sound card  addiction treatment approach      0
# 99   sound card                        device      1
# 803  sound card                 neutral color      0
# 802  sound card                          cell      0
# 805  sound card                     situation      0
#
#         concept   property  label
# 1579  freelance   facility      0
# 1578  freelance     injury      0
# 1581  freelance     entity      0
# 256   freelance    keyword      1
# 1577  freelance    vehicle      0
# 1580  freelance  situation      0
#
#     concept        property  label
# 880   aetna  market dynamic      0
# 114   aetna         company      1
# 878   aetna     insecticide      0
# 881   aetna  modern comfort      0
# 877   aetna   close contact      0
# 879   aetna    coated metal      0
#
#         concept    property  label
# 572  laceration   vegetable      0
# 53   laceration      injury      1
# 576  laceration  ingredient      0
# 575  laceration        herb      0
# 573  laceration       brand      0
# 574  laceration     firearm      0
#
#        concept          property  label
# 258   adelaide              city      1
# 1588  adelaide          beverage      0
# 1589  adelaide         substrate      0
# 1591  adelaide   chelating agent      0
# 1590  adelaide  serial interface      0
# 1587  adelaide           surface      0
#
#      concept       property  label
# 1408   hippo  mobile device      0
# 1411   hippo          breed      0
# 220    hippo         animal      1
# 1410   hippo      treatment      0
# 1407   hippo        surface      0
# 1409   hippo     technology      0
#
#      concept          property  label
# 1133    palm   african country      0
# 1132    palm  serial interface      0
# 1134    palm            liquid      0
# 165     palm     vegetable oil      1
# 1135    palm             sugar      0
# 1136    palm          compound      0
#
#                 concept            property  label
# 490  stem cell research          medication      0
# 488  stem cell research          pyrethroid      0
# 489  stem cell research  infectious disease      0
# 491  stem cell research             allergy      0
# 36   stem cell research               issue      1
# 487  stem cell research              entity      0
#
#               concept                property  label
# 593  electron density               perennial      0
# 594  electron density                    task      0
# 596  electron density  transcription enhancer      0
# 592  electron density                    game      0
# 595  electron density                additive      0
# 57   electron density        plasma parameter      1
#
#          concept      property  label
# 13   thermometer          tool      1
# 373  thermometer      organism      0
# 372  thermometer          part      0
# 376  thermometer     character      0
# 375  thermometer  central bank      0
# 374  thermometer        entity      0
#
#     concept             property  label
# 973     fda            bacterium      0
# 972     fda        hash function      0
# 974     fda               effect      0
# 976     fda     operating system      0
# 975     fda  heavy cleaning duty      0
# 133     fda    regulatory agency      1
#
#       concept                      property  label
# 1305  porsche         aliphatic hydrocarbon      0
# 1302  porsche  low molecular weight heparin      0
# 1306  porsche              a-list celebrity      0
# 1304  porsche            infectious disease      0
# 199   porsche                         brand      1
# 1303  porsche                        method      0
#
#          concept             property  label
# 743  study skill  antioxidizing agent      0
# 742  study skill                breed      0
# 745  study skill         tree service      0
# 87   study skill                topic      1
# 744  study skill              amenity      0
# 746  study skill             beverage      0
#
#          concept             property  label
# 98   quad biking             activity      1
# 799  quad biking  antioxidizing agent      0
# 797  quad biking  synthetic elastomer      0
# 801  quad biking             province      0
# 800  quad biking          alkyl group      0
# 798  quad biking        antihistamine      0
#
#                concept                   property  label
# 1685  loose connection  dispute resolution method      0
# 1686  loose connection                    feature      0
# 1684  loose connection                      brand      0
# 1683  loose connection                  appliance      0
# 1682  loose connection               alkali metal      0
# 278   loose connection                     defect      1
#
#         concept                   property  label
# 1006  mediation         infectious disease      0
# 1004  mediation                   material      0
# 1003  mediation                     factor      0
# 139   mediation  dispute resolution method      1
# 1005  mediation                   additive      0
# 1002  mediation              antihistamine      0
#
#      concept               property  label
# 195   sputum               specimen      1
# 1282  sputum             medication      0
# 1283  sputum  aliphatic hydrocarbon      0
# 1285  sputum               document      0
# 1284  sputum              bacterium      0
# 1286  sputum    synthetic elastomer      0
#
#      concept               property  label
# 1624    sars                emotion      0
# 1625    sars              bacterium      0
# 266     sars     infectious disease      1
# 1623    sars  aliphatic hydrocarbon      0
# 1626    sars                firearm      0
# 1622    sars                feature      0
#
#                 concept                   property  label
# 1785  client s creditor                       herb      0
# 1784  client s creditor                    keyword      0
# 1783  client s creditor  smokeless tobacco product      0
# 1786  client s creditor                alkyl group      0
# 1782  client s creditor           natural disaster      0
# 300   client s creditor                third party      1
#
#      concept      property  label
# 1394   quake  distribution      0
# 1396   quake        entity      0
# 1395   quake       solvent      0
# 1393   quake         state      0
# 217    quake          game      1
# 1392   quake  light source      0
#
#      concept         property  label
# 207   photon         particle      1
# 1344  photon      application      0
# 1345  photon  natural process      0
# 1346  photon      third party      0
# 1343  photon        situation      0
# 1342  photon          vehicle      0
#
#              concept                      property  label
# 706  drug counseling                       vitamin      0
# 705  drug counseling                  lean protein      0
# 702  drug counseling                       product      0
# 79   drug counseling  addiction treatment approach      1
# 704  drug counseling                         skill      0
# 703  drug counseling                      additive      0
#
#               concept         property  label
# 1527  florida georgia             cost      0
# 1529  florida georgia  african country      0
# 245   florida georgia            state      1
# 1528  florida georgia        appliance      0
# 1531  florida georgia     tree service      0
# 1530  florida georgia      cruise line      0
#
#      concept  property  label
# 180   matrix      film      1
# 1207  matrix  activity      0
# 247   matrix     topic      1
# 1209  matrix      city      0
# 1211  matrix  festival      0
# 1208  matrix    sensor      0
# 1210  matrix  document      0
#
#          concept       property  label
# 784  child s age       cytokine      0
# 783  child s age  hash function      0
# 95   child s age         factor      1
# 785  child s age   lean protein      0
# 782  child s age  vegetable oil      0
# 786  child s age      condition      0
#
#          concept             property  label
# 1586  coercivity            pollutant      0
# 1583  coercivity  heavy cleaning duty      0
# 257   coercivity    magnetic property      1
# 1582  coercivity       bronchodilator      0
# 1584  coercivity               injury      0
# 1585  coercivity            condition      0
#
#       concept          property  label
# 1226  cartier  a-list celebrity      0
# 183   cartier             brand      1
# 1222  cartier           symptom      0
# 1223  cartier         perennial      0
# 1224  cartier              herb      0
# 1225  cartier         organelle      0
#
#        concept          property  label
# 609  hay fever           solvent      0
# 610  hay fever  suitable utensil      0
# 607  hay fever         organelle      0
# 608  hay fever           company      0
# 60   hay fever           allergy      1
# 611  hay fever           pattern      0
#
#      concept    property  label
# 1741   chalk   parameter      0
# 291    chalk    material      1
# 1738   chalk  technology      0
# 1737   chalk        herb      0
# 1739   chalk     allergy      0
# 1740   chalk      device      0
#
#     concept                      property  label
# 316   armor                modern comfort      0
# 312   armor  addiction treatment approach      0
# 313   armor                  central bank      0
# 1     armor                          item      1
# 315   armor                   third party      0
# 314   armor                     vegetable      0
#
#          concept            property  label
# 117  real object                tool      1
# 896  real object  infectious disease      0
# 892  real object             product      0
# 895  real object        health issue      0
# 894  real object                role      0
# 893  real object          medication      0
#
#      concept                property  label
# 119  soil ph                  factor      1
# 904  soil ph  transcription enhancer      0
# 902  soil ph               bacterium      0
# 905  soil ph           omron product      0
# 903  soil ph          bronchodilator      0
# 906  soil ph                 service      0
#
#              concept                property  label
# 794  screen printing  transcription enhancer      0
# 793  screen printing      musicianship skill      0
# 796  screen printing            distribution      0
# 792  screen printing                  animal      0
# 795  screen printing          market dynamic      0
# 97   screen printing                  method      1
#
#           concept       property  label
# 1534  cryotherapy        feature      0
# 246   cryotherapy      treatment      1
# 1536  cryotherapy  mobile device      0
# 1533  cryotherapy      pollutant      0
# 1532  cryotherapy      equipment      0
# 1535  cryotherapy        solvent      0
#
#     concept      property  label
# 823   broth          word      0
# 103   broth        liquid      1
# 826   broth     accessory      0
# 822   broth        method      0
# 825   broth  lean protein      0
# 824   broth          film      0
#
#           concept             property  label
# 144   muscle cell                 cell      1
# 1031  muscle cell             festival      0
# 1027  muscle cell  synthetic elastomer      0
# 1029  muscle cell               factor      0
# 1028  muscle cell                virus      0
# 1030  muscle cell            equipment      0
#
#     concept              property  label
# 536    note             accessory      0
# 532    note  electrical appliance      0
# 535    note              organism      0
# 534    note              festival      0
# 45     note           information      1
# 533    note         memory medium      0
#
#     concept                 property  label
# 844    cola             lean protein      0
# 842    cola                  service      0
# 261    cola                    drink      1
# 843    cola                equipment      0
# 846    cola              third party      0
# 845    cola  manipulating identifier      0
# 107    cola                 beverage      1
#
#             concept                       property  label
# 1072  white balance                 disturbed area      0
# 1073  white balance                          virus      0
# 153   white balance                        setting      1
# 1074  white balance                  close contact      0
# 1075  white balance  personal protective equipment      0
# 1076  white balance                          breed      0
#
#     concept        property  label
# 43      eel            fish      1
# 526     eel  bronchodilator      0
# 525     eel            band      0
# 522     eel      lewis acid      0
# 523     eel      amino acid      0
# 524     eel      body fluid      0
#
#                       concept                    property  label
# 563  streptococcus pneumoniae  international organization      0
# 564  streptococcus pneumoniae                 preparation      0
# 566  streptococcus pneumoniae                  amino acid      0
# 562  streptococcus pneumoniae                   cell line      0
# 565  streptococcus pneumoniae                        food      0
# 51   streptococcus pneumoniae                   bacterium      1
#
#                          concept          property  label
# 1689  search engine optimization  optical property      0
# 1687  search engine optimization          exercise      0
# 280   search engine optimization           service      1
# 1688  search engine optimization   natural process      0
# 1690  search engine optimization            artist      0
# 1691  search engine optimization         appliance      0
#
#           concept           property  label
# 410  frankincense     modern comfort      0
# 411  frankincense       complication      0
# 407  frankincense          vegetable      0
# 408  frankincense               word      0
# 20   frankincense      essential oil      1
# 409  frankincense  patient care unit      0
#
#     concept                           property  label
# 391  reggae  serious gastrointestinal toxicity      0
# 388  reggae                              virus      0
# 387  reggae                           province      0
# 390  reggae                   serial interface      0
# 389  reggae                          accessory      0
# 16   reggae                              genre      1
#
#        concept           property  label
# 820  radiohead          substrate      0
# 102  radiohead               band      1
# 819  radiohead             animal      0
# 817  radiohead               item      0
# 818  radiohead           composer      0
# 821  radiohead  magnetic property      0
#
#                    concept                      property  label
# 711  support group meeting                      exercise      0
# 80   support group meeting  addiction treatment approach      1
# 707  support group meeting                       service      0
# 710  support group meeting                 mobile device      0
# 709  support group meeting                  lean protein      0
# 708  support group meeting          electrical appliance      0
#
#      concept         property  label
# 1704    repo            asset      0
# 1706    repo          pattern      0
# 1702    repo  chelating agent      0
# 1705    repo             bird      0
# 1703    repo   sleep disorder      0
# 283     repo        situation      1
#
#       concept         property  label
# 1372  editing            drink      0
# 1374  editing            video      0
# 213   editing          service      1
# 1375  editing  african country      0
# 1373  editing          company      0
# 1376  editing       technology      0
#
#        concept          property  label
# 1037  postcard        identifier      0
# 1040  postcard  serial interface      0
# 146   postcard              item      1
# 1038  postcard          facility      0
# 1041  postcard     medium player      0
# 1039  postcard  personal expense      0
#
#               concept          property  label
# 461  single use glove            factor      0
# 459  single use glove             skill      0
# 457  single use glove           network      0
# 460  single use glove     close contact      0
# 30   single use glove  suitable utensil      1
# 458  single use glove          resource      0
#
#          concept                           property  label
# 476  bae systems                      mobile device      0
# 473  bae systems                             entity      0
# 475  bae systems                           exercise      0
# 472  bae systems  serious gastrointestinal toxicity      0
# 474  bae systems                          condition      0
# 33   bae systems                            company      1
#
#     concept                      property  label
# 40    bagel                          food      1
# 508   bagel  low molecular weight heparin      0
# 509   bagel             patient care unit      0
# 511   bagel                    ingredient      0
# 510   bagel                          area      0
# 507   bagel                    medication      0
#
#     concept     property  label
# 46      cbs      network      1
# 539     cbs      purpose      0
# 538     cbs      feature      0
# 540     cbs  soy product      0
# 541     cbs        sport      0
# 537     cbs        organ      0
#
#              concept                      property  label
# 858  chewing tobacco                      organism      0
# 859  chewing tobacco                  complication      0
# 857  chewing tobacco                 memory medium      0
# 860  chewing tobacco    polyunsaturated fatty acid      0
# 861  chewing tobacco  low molecular weight heparin      0
# 110  chewing tobacco     smokeless tobacco product      1
#
#       concept            property  label
# 91   2d coupe             feature      1
# 766  2d coupe      market dynamic      0
# 765  2d coupe            database      0
# 764  2d coupe                bird      0
# 763  2d coupe  alpha hydroxy acid      0
# 762  2d coupe            beverage      0
#
#        concept                   property  label
# 69   sao paulo                       city      1
# 656  sao paulo                       bird      0
# 652  sao paulo  dispute resolution method      0
# 654  sao paulo                    product      0
# 655  sao paulo                    pattern      0
# 653  sao paulo          magnetic property      0
#
#         concept         property  label
# 365  sacramento      application      0
# 366  sacramento     central bank      0
# 11   sacramento             city      1
# 362  sacramento    hash function      0
# 363  sacramento  natural process      0
# 364  sacramento          journal      0
#
#          concept       property  label
# 1235  tablet pcs        pattern      0
# 1236  tablet pcs           food      0
# 1234  tablet pcs       property      0
# 1233  tablet pcs       material      0
# 1232  tablet pcs          title      0
# 185   tablet pcs  mobile device      1
#
#      concept            property  label
# 1462  levi s               drink      0
# 1464  levi s               title      0
# 231   levi s               brand      1
# 1465  levi s         cruise line      0
# 1466  levi s       blood thinner      0
# 1463  levi s  infectious disease      0
#
#       concept                           property  label
# 149   heptane                            solvent      1
# 240   heptane              aliphatic hydrocarbon      1
# 1054  heptane                      system device      0
# 1055  heptane                           festival      0
# 1052  heptane                      medium player      0
# 1056  heptane  serious gastrointestinal toxicity      0
# 1053  heptane                             effect      0
#
#     concept                   property  label
# 15   kevlar                   material      1
# 383  kevlar  smokeless tobacco product      0
# 384  kevlar                   document      0
# 382  kevlar                insecticide      0
# 385  kevlar          patient care unit      0
# 386  kevlar                     device      0
#
#          concept       property  label
# 367  google maps       organism      0
# 370  google maps      treatment      0
# 371  google maps       language      0
# 368  google maps  neutral color      0
# 369  google maps       resource      0
# 12   google maps    application      1
#
#      concept          property  label
# 406  erosion             genre      0
# 403  erosion         situation      0
# 402  erosion        pyrethroid      0
# 404  erosion  serial interface      0
# 405  erosion             title      0
# 286  erosion            factor      1
# 19   erosion   natural process      1
#
#        concept                           property  label
# 1525  stroller                             liquid      0
# 244   stroller                               item      1
# 1522  stroller                               film      0
# 1523  stroller                   suitable utensil      0
# 1526  stroller                           festival      0
# 1524  stroller  serious gastrointestinal toxicity      0
#
#         concept            property  label
# 331  scheduling            resource      0
# 328  scheduling  alpha hydroxy acid      0
# 327  scheduling    personal expense      0
# 279  scheduling                task      1
# 4    scheduling               issue      1
# 330  scheduling            facility      0
# 329  scheduling          amino acid      0
#
#                           concept                       property  label
# 1772  equipment model designation                        company      0
# 1776  equipment model designation  personal protective equipment      0
# 1773  equipment model designation                          brand      0
# 298   equipment model designation                     identifier      1
# 1774  equipment model designation                         effect      0
# 1775  equipment model designation                        journal      0
#
#     concept                 property  label
# 952     sle                 material      0
# 954     sle  manipulating identifier      0
# 953     sle            antihistamine      0
# 129     sle       autoimmune disease      1
# 955     sle      antioxidizing agent      0
# 956     sle            hash function      0
#
#     concept       property  label
# 503     aim       language      0
# 39      aim           word      1
# 502     aim        journal      0
# 504     aim     regulation      0
# 505     aim   distribution      0
# 506     aim  medium player      0
#
#        concept        property  label
# 1164  nematode      identifier      0
# 1165  nematode         setting      0
# 1163  nematode        additive      0
# 171   nematode        organism      1
# 1166  nematode  sleep disorder      0
# 1162  nematode   medium player      0
#
#          concept           property  label
# 1620  crankshaft          perennial      0
# 1618  crankshaft       tree service      0
# 265   crankshaft               part      1
# 1617  crankshaft    chelating agent      0
# 1619  crankshaft           compound      0
# 1621  crankshaft  magnetic property      0
#
#        concept                           property  label
# 615  professor                       complication      0
# 614  professor                           facility      0
# 616  professor                              drink      0
# 612  professor                            symptom      0
# 613  professor  serious gastrointestinal toxicity      0
# 61   professor                              title      1
#
#             concept                       property  label
# 162   safety goggle  personal protective equipment      1
# 1121  safety goggle                   complication      0
# 1119  safety goggle                         defect      0
# 1120  safety goggle                  neutral color      0
# 1118  safety goggle       eastern european country      0
# 1117  safety goggle                           word      0
#
#     concept               property  label
# 571  roller  aliphatic hydrocarbon      0
# 52   roller                   part      1
# 567  roller                  nsaid      0
# 570  roller                  state      0
# 568  roller                   herb      0
# 569  roller                journal      0
#
#          concept           property  label
# 1183  web server       coated metal      0
# 1182  web server      memory medium      0
# 175   web server        application      1
# 1185  web server           activity      0
# 1184  web server  patient care unit      0
# 1186  web server          appliance      0
#
#     concept                  property  label
# 514    aloe  eastern european country      0
# 513    aloe            funding source      0
# 516    aloe                    entity      0
# 512    aloe                 perennial      0
# 41     aloe                ingredient      1
# 515    aloe                   symptom      0
#
#      concept                   property  label
# 82   kissing              close contact      1
# 718  kissing  dispute resolution method      0
# 717  kissing                       cost      0
# 720  kissing                  parameter      0
# 721  kissing                insecticide      0
# 719  kissing                  accessory      0
#
#              concept                       property  label
# 154   vacuum cleaner           electrical appliance      1
# 1080  vacuum cleaner                   coated metal      0
# 1081  vacuum cleaner                  mobile device      0
# 1079  vacuum cleaner                           item      0
# 1077  vacuum cleaner                  plant hormone      0
# 1078  vacuum cleaner  personal protective equipment      0
#
#               concept         property  label
# 939  maintenance cost          allergy      0
# 126  maintenance cost             cost      1
# 940  maintenance cost      alkyl group      0
# 938  maintenance cost     alkali metal      0
# 941  maintenance cost         particle      0
# 937  maintenance cost  eating disorder      0
#
#           concept          property  label
# 150   civil right             issue      1
# 1060  civil right          specimen      0
# 1061  civil right     essential oil      0
# 1058  civil right  optical property      0
# 1059  civil right         appliance      0
# 1057  civil right            defect      0
#
#     concept     property  label
# 781  dosage      service      0
# 778  dosage   amino acid      0
# 779  dosage  soy product      0
# 780  dosage     resource      0
# 777  dosage     property      0
# 94   dosage       factor      1
#
#          concept     property  label
# 317  forgiveness        sugar      0
# 320  forgiveness        organ      0
# 319  forgiveness  insecticide      0
# 318  forgiveness        asset      0
# 2    forgiveness        topic      1
# 321  forgiveness    equipment      0
#
#                 concept        property  label
# 1279  dextroamphetamine     cruise line      0
# 1281  dextroamphetamine         pattern      0
# 1277  dextroamphetamine  market dynamic      0
# 194   dextroamphetamine       stimulant      1
# 1278  dextroamphetamine          effect      0
# 1280  dextroamphetamine         company      0
#
#                         concept             property  label
# 1698  environmental degradation                 herb      0
# 1700  environmental degradation              journal      0
# 1701  environmental degradation  heavy cleaning duty      0
# 282   environmental degradation                issue      1
# 1697  environmental degradation               injury      0
# 1699  environmental degradation             facility      0
#
#          concept      property  label
# 900  vaccination   insecticide      0
# 899  vaccination       symptom      0
# 901  vaccination  distribution      0
# 118  vaccination       service      1
# 897  vaccination      province      0
# 898  vaccination   credit card      0
#
#      concept       property  label
# 637  holster         liquid      0
# 638  holster       exercise      0
# 640  holster      substrate      0
# 66   holster      accessory      1
# 639  holster  system device      0
# 641  holster  close contact      0
#
#       concept           property  label
# 1370  sunroof   optical property      0
# 212   sunroof            feature      1
# 1371  sunroof              state      0
# 1367  sunroof  patient care unit      0
# 1369  sunroof     market dynamic      0
# 1368  sunroof         medication      0
#
#     concept          property  label
# 89    tamil          language      1
# 754   tamil          software      0
# 753   tamil         appliance      0
# 756   tamil        identifier      0
# 752   tamil  serial interface      0
# 755   tamil          exercise      0
#
#             concept       property  label
# 1382  freeze drying       exercise      0
# 1386  freeze drying      organelle      0
# 215   freeze drying         method      1
# 1383  freeze drying       organism      0
# 1384  freeze drying  vegetable oil      0
# 1385  freeze drying  memory medium      0
#
#         concept       property  label
# 1154  malathion       beverage      0
# 1156  malathion      incentive      0
# 1153  malathion        setting      0
# 169   malathion    insecticide      1
# 1155  malathion     identifier      0
# 1152  malathion  blood thinner      0
#
#        concept                 property  label
# 1101  overhead                    drink      0
# 158   overhead                     cost      1
# 1100  overhead               pyrethroid      0
# 1098  overhead  manipulating identifier      0
# 1097  overhead      heavy cleaning duty      0
# 1099  overhead              information      0
#
#          concept     property  label
# 377  metal alloy  credit card      0
# 14   metal alloy     material      1
# 380  metal alloy      vehicle      0
# 379  metal alloy        virus      0
# 378  metal alloy       artist      0
# 381  metal alloy    bacterium      0
#
#      concept        property  label
# 1437  osprey        compound      0
# 1441  osprey  modern comfort      0
# 226   osprey            bird      1
# 1440  osprey          entity      0
# 1438  osprey        activity      0
# 1439  osprey    light source      0
#
#                           concept                property  label
# 1491  rous sarcoma virus enhancer      autoimmune disease      0
# 1487  rous sarcoma virus enhancer                    bird      0
# 236   rous sarcoma virus enhancer  transcription enhancer      1
# 1488  rous sarcoma virus enhancer               parameter      0
# 1490  rous sarcoma virus enhancer                   brand      0
# 1489  rous sarcoma virus enhancer               bacterium      0
#
#            concept      property  label
# 294   hospital bed          item      1
# 1754  hospital bed    amino acid      0
# 1756  hospital bed          herb      0
# 1755  hospital bed  health issue      0
# 1753  hospital bed          part      0
# 1752  hospital bed      composer      0
#
#                        concept          property  label
# 430  microwave motion detector         accessory      0
# 429  microwave motion detector          material      0
# 24   microwave motion detector     system device      1
# 427  microwave motion detector              item      0
# 431  microwave motion detector  operating system      0
# 428  microwave motion detector          facility      0
#
#        concept                   property  label
# 812  developer          regulatory agency      0
# 101  developer                       role      1
# 813  developer                 regulation      0
# 816  developer                   activity      0
# 815  developer  dispute resolution method      0
# 814  developer                       item      0
#
#           concept             property  label
# 864  washing wall                 band      0
# 866  washing wall             facility      0
# 862  washing wall                sport      0
# 863  washing wall        mobile device      0
# 865  washing wall     suitable utensil      0
# 111  washing wall  heavy cleaning duty      1
#
#           concept   property  label
# 1576  pulse width   software      0
# 1572  pulse width   organism      0
# 1575  pulse width     object      0
# 1573  pulse width     defect      0
# 255   pulse width  parameter      1
# 1574  pulse width    service      0
#
#                   concept                    property  label
# 558  docosahexaenoic acid                     surface      0
# 50   docosahexaenoic acid  polyunsaturated fatty acid      1
# 560  docosahexaenoic acid               neutral color      0
# 557  docosahexaenoic acid                    composer      0
# 559  docosahexaenoic acid                    festival      0
# 561  docosahexaenoic acid                     network      0
#
#           concept             property  label
# 1230  new balance              allergy      0
# 1229  new balance              prophet      0
# 184   new balance                brand      1
# 1228  new balance          soy product      0
# 1231  new balance          application      0
# 1227  new balance  synthetic elastomer      0
#
#             concept                       property  label
# 250   blood testing                        service      1
# 1548  blood testing               a-list celebrity      0
# 1551  blood testing                       province      0
# 1550  blood testing             alpha hydroxy acid      0
# 1547  blood testing  personal protective equipment      0
# 1549  blood testing                       compound      0
#
#      concept                property  label
# 1635      b2  transcription enhancer      0
# 1634      b2                   virus      0
# 1632      b2   aliphatic hydrocarbon      0
# 1636      b2                 feature      0
# 268       b2                 vitamin      1
# 1633      b2               condition      0
#
#          concept                   property  label
# 1015  galvanized  smokeless tobacco product      0
# 141   galvanized               coated metal      1
# 1014  galvanized             sleep disorder      0
# 1013  galvanized                  stimulant      0
# 1016  galvanized                   exercise      0
# 1012  galvanized                  bacterium      0
#
#          concept       property  label
# 681  gibberellin   neuropeptide      0
# 680  gibberellin       specimen      0
# 677  gibberellin           tool      0
# 74   gibberellin  plant hormone      1
# 679  gibberellin      treatment      0
# 678  gibberellin   central bank      0
#
#       concept                       property  label
# 308  goldfish                    credit card      0
# 0    goldfish                           fish      1
# 309  goldfish  personal protective equipment      0
# 310  goldfish                  neutral color      0
# 311  goldfish                          virus      0
# 307  goldfish                       organism      0
#
#                           concept          property  label
# 932  health insurance portability              food      0
# 125  health insurance portability        regulation      1
# 935  health insurance portability          activity      0
# 934  health insurance portability             state      0
# 933  health insurance portability  a-list celebrity      0
# 936  health insurance portability       preparation      0
#
#      concept                    property  label
# 1251    nato            serial interface      0
# 1248    nato             chelating agent      0
# 188     nato  international organization      1
# 1247    nato                      liquid      0
# 1249    nato                  technology      0
# 1250    nato                       title      0
#
#       concept        property  label
# 1017  fasting            item      0
# 142   fasting     preparation      1
# 1018  fasting            part      0
# 1021  fasting  funding source      0
# 1020  fasting    alkali metal      0
# 1019  fasting         service      0
#
#        concept          property  label
# 1542  marriott      coated metal      0
# 1544  marriott  plasma parameter      0
# 249   marriott           company      1
# 1543  marriott    sleep disorder      0
# 1546  marriott         condition      0
# 1545  marriott     omron product      0
#
#      concept          property  label
# 628  lacoste           pattern      0
# 630  lacoste  suitable utensil      0
# 629  lacoste            defect      0
# 64   lacoste             brand      1
# 631  lacoste            liquid      0
# 627  lacoste           mineral      0
#
#      concept                 property  label
# 1239    bill                 province      0
# 1238    bill                appliance      0
# 1241    bill  manipulating identifier      0
# 1240    bill         serial interface      0
# 1237    bill         natural disaster      0
# 186     bill                 document      1
#
#      concept         property  label
# 1107   pitch        incentive      0
# 1111   pitch          protein      0
# 160    pitch        parameter      1
# 1109   pitch          symptom      0
# 1110   pitch          feature      0
# 1108   pitch  african country      0
#
#         concept  property  label
# 856  distortion      city      0
# 855  distortion      cost      0
# 853  distortion    injury      0
# 854  distortion   feature      0
# 109  distortion    effect      1
# 852  distortion  specimen      0
#
#             concept              property  label
# 1447  diesel engine       african country      0
# 228   diesel engine     combustion engine      1
# 1451  diesel engine            regulation      0
# 1448  diesel engine  limited circumstance      0
# 1450  diesel engine         essential oil      0
# 1449  diesel engine              software      0
#
#             concept             property  label
# 838  herniated disc       disturbed area      0
# 839  herniated disc                 area      0
# 840  herniated disc           lewis acid      0
# 837  herniated disc           medication      0
# 106  herniated disc            condition      1
# 841  herniated disc  heavy cleaning duty      0
#
#         concept          property  label
# 1378  first aid     essential oil      0
# 1379  first aid         cell line      0
# 1377  first aid  natural disaster      0
# 1381  first aid          cytokine      0
# 214   first aid             skill      1
# 1380  first aid         character      0
#
#      concept           property  label
# 1744      5s               part      0
# 1743      5s  magnetic property      0
# 1745      5s           industry      0
# 1746      5s     sleep disorder      0
# 1742      5s      essential oil      0
# 292       5s               tool      1
#
#           concept             property  label
# 1423  forest fire      african country      0
# 1424  forest fire               artist      0
# 1426  forest fire               device      0
# 223   forest fire     natural disaster      1
# 1422  forest fire              setting      0
# 1425  forest fire  heavy cleaning duty      0
#
#          concept         property  label
# 393  hydrocarbon        bacterium      0
# 396  hydrocarbon             food      0
# 17   hydrocarbon        pollutant      1
# 394  hydrocarbon        stimulant      0
# 392  hydrocarbon        organelle      0
# 395  hydrocarbon  eating disorder      0
#
#     concept   property  label
# 836   dubai      drink      0
# 105   dubai       city      1
# 832   dubai  cell line      0
# 833   dubai      virus      0
# 834   dubai   language      0
# 835   dubai       item      0
#
#              concept                  property  label
# 1763  czech republic         combustion engine      0
# 1764  czech republic                     state      0
# 1766  czech republic                    artist      0
# 1765  czech republic                    liquid      0
# 296   czech republic  eastern european country      1
# 1762  czech republic                  specimen      0
#
#     concept            property  label
# 355   grant    suitable utensil      0
# 306   grant      funding source      1
# 9     grant           incentive      1
# 356   grant  autoimmune disease      0
# 353   grant          lewis acid      0
# 354   grant        lean protein      0
# 352   grant          medication      0
#
#              concept      property  label
# 1471  optical sensor  coated metal      0
# 1470  optical sensor          band      0
# 1467  optical sensor  health issue      0
# 1468  optical sensor         asset      0
# 232   optical sensor        sensor      1
# 1469  optical sensor       company      0
#
#     concept   property  label
# 947   suede    setting      0
# 948   suede  equipment      0
# 950   suede       meat      0
# 128   suede   material      1
# 949   suede   province      0
# 951   suede  character      0
#
#           concept       property  label
# 1258  part number  essential oil      0
# 1260  part number           game      0
# 190   part number    information      1
# 1257  part number          topic      0
# 1259  part number          organ      0
# 1261  part number     technology      0
#
#                             concept    property  label
# 830  nonsteroidal anti inflammatory       issue      0
# 827  nonsteroidal anti inflammatory   condition      0
# 831  nonsteroidal anti inflammatory       state      0
# 828  nonsteroidal anti inflammatory     surface      0
# 829  nonsteroidal anti inflammatory      device      0
# 104  nonsteroidal anti inflammatory  medication      1
#
#             concept                    property  label
# 1505  zinc chloride                     amenity      0
# 1503  zinc chloride                     company      0
# 239   zinc chloride                  lewis acid      1
# 1502  zinc chloride  international organization      0
# 1504  zinc chloride                       asset      0
# 1506  zinc chloride                   organelle      0
#
#      concept        property  label
# 1501  driver         pattern      0
# 238   driver  market dynamic      1
# 1499  driver         symptom      0
# 1497  driver      technology      0
# 1498  driver        material      0
# 1500  driver    coated metal      0
#
#            concept             property  label
# 1356  conservation                 film      0
# 209   conservation                topic      1
# 1354  conservation  heavy cleaning duty      0
# 1355  conservation                video      0
# 1353  conservation             beverage      0
# 1352  conservation                 cost      0
#
#       concept                    property  label
# 635  superman                      device      0
# 65   superman                   character      1
# 633  superman  international organization      0
# 632  superman                    database      0
# 636  superman                        fish      0
# 634  superman                        role      0
#
#              concept             property  label
# 1144  sodium sulfite       disturbed area      0
# 167   sodium sulfite  antioxidizing agent      1
# 1145  sodium sulfite                 city      0
# 1146  sodium sulfite        blood thinner      0
# 1143  sodium sulfite                 herb      0
# 1142  sodium sulfite              setting      0
#
#      concept        property  label
# 1791   liver   memory medium      0
# 1790   liver   hash function      0
# 1788   liver         surface      0
# 1787   liver          method      0
# 301    liver           organ      1
# 1789   liver  bronchodilator      0
#
#            concept                       property  label
# 216   canned goods                           item      1
# 1391  canned goods                natural process      0
# 1387  canned goods                   health issue      0
# 1388  canned goods                      perennial      0
# 1390  canned goods  personal protective equipment      0
# 1389  canned goods                      equipment      0
#
#         concept        property  label
# 727  permethrin  sleep disorder      0
# 84   permethrin      pyrethroid      1
# 728  permethrin           title      0
# 729  permethrin        composer      0
# 730  permethrin           state      0
# 731  permethrin            cost      0
#
#               concept       property  label
# 1475  jackson pollock        surface      0
# 1472  jackson pollock       activity      0
# 1473  jackson pollock       province      0
# 233   jackson pollock         artist      1
# 1476  jackson pollock  essential oil      0
# 1474  jackson pollock           bird      0
#
#                concept                   property  label
# 274   wireless network           serial interface      1
# 1663  wireless network  smokeless tobacco product      0
# 1662  wireless network                       film      0
# 1666  wireless network                       part      0
# 1664  wireless network                    solvent      0
# 1665  wireless network        synthetic elastomer      0
#
#        concept     property  label
# 875  neck pain  third party      0
# 113  neck pain      symptom      1
# 876  neck pain  information      0
# 872  neck pain       artist      0
# 873  neck pain         cost      0
# 874  neck pain     province      0
#
#                   concept                       property  label
# 771  chemical composition                       festival      0
# 769  chemical composition               a-list celebrity      0
# 767  chemical composition  personal protective equipment      0
# 770  chemical composition                         object      0
# 768  chemical composition                          breed      0
# 92   chemical composition                         factor      1
#
#        concept                      property  label
# 1095  ph value                      province      0
# 1093  ph value  addiction treatment approach      0
# 1096  ph value                         state      0
# 1092  ph value               eating disorder      0
# 157   ph value                     parameter      1
# 1094  ph value    polyunsaturated fatty acid      0
#
#        concept           property  label
# 1199  ideology          character      0
# 1198  ideology     disturbed area      0
# 178   ideology             factor      1
# 1197  ideology               food      0
# 1200  ideology      omron product      0
# 1201  ideology  regulatory agency      0
#
#      concept                      property  label
# 1445    envy                     condition      0
# 1442    envy                     incentive      0
# 1443    envy                      resource      0
# 1446    envy     smokeless tobacco product      0
# 1444    envy  addiction treatment approach      0
# 227     envy                       emotion      1
#
#                 concept                 property  label
# 776  hormonal imbalance                     herb      0
# 772  hormonal imbalance                   entity      0
# 774  hormonal imbalance            hash function      0
# 775  hormonal imbalance  manipulating identifier      0
# ...
# 88   polyphenol          compound      1
# 748  polyphenol              city      0
# 749  polyphenol              task      0
# 750  polyphenol  suitable utensil      0
# 747  polyphenol         perennial      0
#
#      concept                property  label
# 734  weibull                    meat      0
# 736  weibull  transcription enhancer      0
# 732  weibull                  defect      0
# 733  weibull                    bird      0
# 85   weibull            distribution      1
# 735  weibull             soy product      0
#
#        concept                 property  label
# 1416  hamilton               amino acid      0
# 1415  hamilton                    breed      0
# 1412  hamilton  manipulating identifier      0
# 1413  hamilton               identifier      0
# 221   hamilton                     city      1
# 1414  hamilton         plasma parameter      0
#
#           concept            property  label
# 1313  dispersants              device      0
# 1314  dispersants   combustion engine      0
# 1312  dispersants               topic      0
# 1316  dispersants              artist      0
# 1315  dispersants  alpha hydroxy acid      0
# 201   dispersants            additive      1
#
#                 concept                   property  label
# 578  wedding invitation                insecticide      0
# 579  wedding invitation               tree service      0
# 54   wedding invitation                    purpose      1
# 580  wedding invitation  smokeless tobacco product      0
# 577  wedding invitation               distribution      0
# 581  wedding invitation   eastern european country      0
#
#       concept          property  label
# 334  template           protein      0
# 5    template           feature      1
# 336  template  plasma parameter      0
# 335  template              part      0
# 333  template              cost      0
# 332  template    modern comfort      0
#
#             concept                 property  label
# 870  black or white                    genre      0
# 871  black or white  manipulating identifier      0
# 868  black or white                parameter      0
# 867  black or white                 facility      0
# 112  black or white                    video      1
# 869  black or white                   device      0
#
#       concept property  label
# 1429  mannose   device      0
# 1428  mannose     band      0
# 1430  mannose     task      0
# 224   mannose    sugar      1
# 1427  mannose    skill      0
# 1431  mannose     area      0
#
#     concept         property  label
# 913   adida         property      0
# 121   adida            brand      1
# 914   adida            brand      0
# 912   adida  eating disorder      0
# 916   adida          firearm      0
# 915   adida             area      0
#
#          concept          property  label
# 419  transferrin             asset      0
# 418  transferrin        pyrethroid      0
# 417  transferrin  suitable utensil      0
# 420  transferrin              task      0
# 421  transferrin           pattern      0
# 22   transferrin           protein      1
#
#                   concept                    property  label
# 1571  european commission       aliphatic hydrocarbon      0
# 1570  european commission                     vehicle      0
# 1567  european commission                       sugar      0
# 1569  european commission                      method      0
# 1568  european commission             african country      0
# 254   european commission  international organization      1
#
#      concept           property  label
# 1695    lisp           composer      0
# 281     lisp           language      1
# 1696    lisp           software      0
# 1693    lisp               role      0
# 1694    lisp          perennial      0
# 1692    lisp  combustion engine      0
#
#         concept            property  label
# 1484  albuterol           bacterium      0
# 1483  albuterol           situation      0
# 1485  albuterol  autoimmune disease      0
# 235   albuterol      bronchodilator      1
# 1482  albuterol           accessory      0
# 1486  albuterol            resource      0
#
#       concept                   property  label
# 1759  gauteng  dispute resolution method      0
# 1758  gauteng                       city      0
# 1760  gauteng                     defect      0
# 295   gauteng                   province      1
# 1761  gauteng             modern comfort      0
# 1757  gauteng                   material      0
#
#      concept   property  label
# 1631   boxer   particle      0
# 1630   boxer  situation      0
# 1628   boxer     method      0
# 1627   boxer   property      0
# 1629   boxer    emotion      0
# 267    boxer      breed      1
#
#              concept           property  label
# 1420  weight lifting  magnetic property      0
# 1417  weight lifting     disturbed area      0
# 222   weight lifting              sport      1
# 1421  weight lifting        third party      0
# 1419  weight lifting             entity      0
# 1418  weight lifting               meat      0
#
#          concept          property  label
# 807  safety rule          particle      0
# 100  safety rule          document      1
# 809  safety rule       alkyl group      0
# 810  safety rule          compound      0
# 811  safety rule           mineral      0
# 808  safety rule  a-list celebrity      0
#
#           concept             property  label
# 1204  social norm        medium player      0
# 1206  social norm  heavy cleaning duty      0
# 1203  social norm        close contact      0
# 1205  social norm    regulatory agency      0
# 179   social norm               factor      1
# 1202  social norm             beverage      0
#
#            concept                   property  label
# 1810  tree removal                   resource      0
# 1809  tree removal                      organ      0
# 1811  tree removal       limited circumstance      0
# 305   tree removal               tree service      1
# 1808  tree removal                  cell line      0
# 1807  tree removal  dispute resolution method      0
#
#                      concept         property  label
# 1731  restless legs syndrome       identifier      0
# 1728  restless legs syndrome             cost      0
# 1727  restless legs syndrome  natural process      0
# 289   restless legs syndrome   sleep disorder      1
# 1729  restless legs syndrome            organ      0
# 1730  restless legs syndrome         festival      0
#
#      concept               property  label
# 1311     hcv                product      0
# 1307     hcv                 animal      0
# 200      hcv                  virus      1
# 1310     hcv              situation      0
# 1309     hcv                company      0
# 1308     hcv  aliphatic hydrocarbon      0
#
#             concept           property  label
# 686  vaccinia virus  magnetic property      0
# 75   vaccinia virus              virus      1
# 682  vaccinia virus            network      0
# 683  vaccinia virus           festival      0
# 685  vaccinia virus           software      0
# 684  vaccinia virus   plasma parameter      0
#
#             concept property  label
# 1366  shopping mall  symptom      0
# 211   shopping mall  amenity      1
# 1363  shopping mall     city      0
# 1362  shopping mall  surface      0
# 1364  shopping mall    organ      0
# 1365  shopping mall     part      0
#
#          concept                      property  label
# 1009  enoxaparin        transcription enhancer      0
# 140   enoxaparin  low molecular weight heparin      1
# 1011  enoxaparin                         breed      0
# 1007  enoxaparin                         video      0
# 1008  enoxaparin                   soy product      0
# 1010  enoxaparin                      particle      0
#
#      concept          property  label
# 1515  plavix  natural disaster      0
# 1514  plavix          additive      0
# 1516  plavix        regulation      0
# 1512  plavix        medication      0
# 242   plavix     blood thinner      1
# 1513  plavix           company      0
#
#        concept                  property  label
# 479  key chain                 situation      0
# 480  key chain                   purpose      0
# 477  key chain  eastern european country      0
# 34   key chain                      item      1
# 481  key chain                  resource      0
# 478  key chain                      meat      0
#
#           concept                      property  label
# 77   sober living  addiction treatment approach      1
# 692  sober living                      database      0
# 694  sober living                          word      0
# 695  sober living            alpha hydroxy acid      0
# 693  sober living                      software      0
# 696  sober living                     character      0
#
#             concept               property  label
# 174   chemical peel              treatment      1
# 1180  chemical peel                   item      0
# 1181  chemical peel                  sport      0
# 1177  chemical peel                company      0
# 1178  chemical peel                   food      0
# 1179  chemical peel  aliphatic hydrocarbon      0
#
#              concept                       property  label
# 1130  telephone call                      parameter      0
# 1129  telephone call                   light source      0
# 1127  telephone call  personal protective equipment      0
# 164   telephone call               personal expense      1
# 1128  telephone call                african country      0
# 1131  telephone call                          skill      0
#
#                  concept              property  label
# 598  grand jury subpoena               mineral      0
# 600  grand jury subpoena               allergy      0
# 58   grand jury subpoena  limited circumstance      1
# 597  grand jury subpoena              property      0
# 601  grand jury subpoena              specimen      0
# 599  grand jury subpoena             condition      0
#
#                concept            property  label
# 1361  laundry facility         credit card      0
# 1357  laundry facility  autoimmune disease      0
# 1360  laundry facility       vegetable oil      0
# 1358  laundry facility       neutral color      0
# 1359  laundry facility     chelating agent      0
# 210   laundry facility             amenity      1
#
#         concept            property  label
# 439  ultrasonic  autoimmune disease      0
# 437  ultrasonic        light source      0
# 26   ultrasonic       system device      1
# 440  ultrasonic              injury      0
# 438  ultrasonic            specimen      0
# 441  ultrasonic           character      0
#
#              concept            property  label
# 1091  clothes washer            material      0
# 1090  clothes washer           pollutant      0
# 1088  clothes washer             allergy      0
# 1089  clothes washer                herb      0
# 156   clothes washer           appliance      1
# 1087  clothes washer  alpha hydroxy acid      0
#
#         concept      property  label
# 1291  mast cell          game      0
# 1287  mast cell  health issue      0
# 1290  mast cell         drink      0
# 1289  mast cell  distribution      0
# 196   mast cell          cell      1
# 1288  mast cell         sugar      0
#
#           concept           property  label
# 10   agricultural           industry      1
# 359  agricultural      system device      0
# 361  agricultural               meat      0
# 358  agricultural        application      0
# 360  agricultural               fish      0
# 357  agricultural  combustion engine      0
#
#       concept                property  label
# 299   slipper          modern comfort      1
# 1777  slipper                   topic      0
# 1781  slipper        a-list celebrity      0
# 1780  slipper                software      0
# 1779  slipper                specimen      0
# 1778  slipper  transcription enhancer      0
#
#         concept                           property  label
# 590  ulceration                          situation      0
# 591  ulceration                              virus      0
# 588  ulceration                      memory medium      0
# 589  ulceration         polyunsaturated fatty acid      0
# 587  ulceration                   suitable utensil      0
# 56   ulceration  serious gastrointestinal toxicity      1
#
#            concept                      property  label
# 1507  binge eating  low molecular weight heparin      0
# 1508  binge eating                    lewis acid      0
# 1510  binge eating                     stimulant      0
# 241   binge eating               eating disorder      1
# 1511  binge eating                  complication      0
# 1509  binge eating                       firearm      0
#
#     concept      property  label
# 499  spacer  tree service      0
# 500  spacer       vehicle      0
# 497  spacer      cytokine      0
# 38   spacer       product      1
# 498  spacer     parameter      0
# 501  spacer   alkyl group      0
#
#      concept          property  label
# 264      tan     neutral color      1
# 1613     tan           feature      0
# 1612     tan  serial interface      0
# 1615     tan     mobile device      0
# 1614     tan      coated metal      0
# 1616     tan         equipment      0
#
#             concept             property  label
# 997   janet jackson    magnetic property      0
# 999   janet jackson             cytokine      0
# 1001  janet jackson  antioxidizing agent      0
# 138   janet jackson     a-list celebrity      1
# 1000  janet jackson            stimulant      0
# 998   janet jackson         central bank      0
#
#         concept       property  label
# 263   aggregate       material      1
# 1607  aggregate  antihistamine      0
# 1609  aggregate           part      0
# 1608  aggregate         method      0
# 1610  aggregate       beverage      0
# 1611  aggregate      treatment      0
#
#      concept                   property  label
# 988  autocad        heavy cleaning duty      0
# 990  autocad  dispute resolution method      0
# 136  autocad                   software      1
# 989  autocad                    feature      0
# 987  autocad                application      0
# 991  autocad                    company      0
#
#      concept   property  label
# 1221  stereo      breed      0
# 1220  stereo   province      0
# 1219  stereo  parameter      0
# 182   stereo       item      1
# 1218  stereo      genre      0
# 1217  stereo      nsaid      0
#
#                  concept    property  label
# 1597  management science    material      0
# 1601  management science  body fluid      0
# 260   management science     journal      1
# 1598  management science       organ      0
# 1600  management science    facility      0
# 1599  management science    organism      0
#
#                concept  property  label
# 120  ethnic background    factor      1
# 911  ethnic background  province      0
# 908  ethnic background   mineral      0
# 907  ethnic background   prophet      0
# 909  ethnic background     issue      0
# 910  ethnic background   feature      0
#
#       concept                  property  label
# 545  bulgaria                     topic      0
# 543  bulgaria        musicianship skill      0
# 544  bulgaria                     brand      0
# 546  bulgaria          optical property      0
# 542  bulgaria                      fish      0
# 47   bulgaria  eastern european country      1
#
#          concept      property  label
# 1102  amiodarone    pyrethroid      0
# 1106  amiodarone  distribution      0
# 159   amiodarone    medication      1
# 1105  amiodarone          meat      0
# 1104  amiodarone      specimen      0
# 1103  amiodarone          game      0
#
#     concept         property  label
# 412  rwanda          mineral      0
# 21   rwanda  african country      1
# 416  rwanda             game      0
# 415  rwanda          firearm      0
# 414  rwanda         facility      0
# 413  rwanda         exercise      0
#
#           concept          property  label
# 229   glastonbury          festival      1
# 1452  glastonbury   chelating agent      0
# 1456  glastonbury             state      0
# 1455  glastonbury           solvent      0
# 1453  glastonbury           journal      0
# 1454  glastonbury  optical property      0
#
#        concept             property  label
# 649  sweetener                 game      0
# 68   sweetener           ingredient      1
# 647  sweetener  antioxidizing agent      0
# 648  sweetener           medication      0
# 650  sweetener             software      0
# 651  sweetener     suitable utensil      0

# %%
train_df.dtypes

# %%
def generate_negative_data(data_df, num_neg_pair=1):
    
    data_df.reset_index(drop=True, inplace=True)
    
    #print ('data_df.index :',data_df.index)
        
    negative_data = []
    
    concept_list = data_df['concept'].unique()

    for concept in concept_list:
        
        negative_data_for_concept = []

        positive_data = data_df[data_df["concept"] == concept]
        #positive_data_index = data_df[data_df["concept"] == concept].index
        positive_data_index = np.array(positive_data.index)
        num_positive_data = len(positive_data_index)

        rest_df = data_df.drop(positive_data_index)
        rest_df.reset_index(drop=True, inplace=True)
        rest_df_idx = rest_df.index
        
        pos_or_negative = np.random.choice(['neg_concept', 'neg_property'], size=len(positive_data_index))
        
        num_neg_concept = Counter(pos_or_negative).get('neg_concept')
        num_neg_property = Counter(pos_or_negative).get('neg_property')
                
        print ('\n')
        print ('--' * 50 )
        print ('Concept :', concept)
        print ('len(positive_data):', len(positive_data))
        print ('num_neg_concept :',  num_neg_concept)
        print ('num_neg_property :', num_neg_property)
        print ('postitive_data_index :', positive_data_index)
        print ('\npositive_data:')
        print (positive_data)
        
        neg_concept_data = []
        neg_property_data = []
        
        
        # indexes of the records for which concept will be corrupted.
        if num_neg_concept is not None:
            
            neg_concept_record_idx = np.random.choice(positive_data_index, size=num_neg_concept)
            neg_concept = rest_df.sample(n = num_neg_pair * num_neg_concept)['concept'].to_numpy()
            neg_concept_split = np.split(neg_concept, len(neg_concept_record_idx))
            
            print ('\nneg_concepts')
            print (neg_concept)
            
            for array, idx in zip(neg_concept_split, neg_concept_record_idx):
                neg_concept_data.extend([(con, positive_data.loc[idx]['property'], 0) for con in array])                
        else:
            print ('num_neg_concept in None')
            neg_concept_record_idx = []
        
        print ('Negative concept for true property')
        print (neg_concept_data)

                
        if num_neg_property is not None:
            
            # indexes of the records for which property will be corrupted.
            #neg_property_record_idx = np.array([idx for idx in positive_data_index if idx not in neg_concept_record_idx])
            
            neg_property = rest_df.sample(n=num_neg_pair * num_neg_property)['property'].to_list()
            print ('\nneg_property :', neg_property)
            
            neg_property_data.extend([(concept, neg_prop, 0) for neg_prop in neg_property])
            
        print ('Negative Property data for true Concept :')
        print (neg_property_data)
            
        negative_data_for_concept.extend(neg_concept_data)
        negative_data_for_concept.extend(neg_property_data)
        
        print ('\nNumber of Negative Data For Concept :', len(negative_data_for_concept))
        print ('negative_data_for_concept:')
        print (negative_data_for_concept)
        
        negative_data.append(negative_data_for_concept)
        

    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)
    
    
    all_data = pd.concat([data_df, negative_data_df], ignore_index=True)
    
    all_data = all_data.sample(frac=1)
    all_data.drop_duplicates(inplace=True)
    
    print ('\nFinished Generating Data For One Set')
    print ('len(all_data) :', len(all_data))
    
    return all_data

# %%
print ('#' * 50)
print ('Generating Negative Train Data')

# %%
print ('\n Training Data')

# %%
pos_neg_train_df = generate_negative_data(train_df, num_neg_pair=num_neg_pair)
pos_neg_train_df.to_csv('data/65k_train_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Train Record Before Negative Data:', len(train_df))
print ('Train Record After Negative Data:', len(pos_neg_train_df))

# %%
print ('#' * 50)
print ('Generating Negative Valid Data')
print ('\n Validation Data')
pos_neg_val_df = generate_negative_data(valid_df, num_neg_pair=num_neg_pair)
pos_neg_val_df.to_csv('data/65k_valid_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Validation Record Before Negative Data:', len(valid_df))
print ('Validation Record After Negative Data:', len(pos_neg_val_df))

# %%
print ('#' * 50)
print ('Generating Negative Test Data')

print ('\n Test Data')
pos_neg_test_df = generate_negative_data(test_df, num_neg_pair=num_neg_pair)
pos_neg_test_df.to_csv('data/65k_test_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Test Record Before Negative Data:', len(test_df))
print ('Test Record After Negative Data:', len(pos_neg_test_df))
