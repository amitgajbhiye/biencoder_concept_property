# %%
import torch
import pandas as pd
import numpy as np

from collections import Counter

# %%
#file_path = "/scratch/c.scmag3/conceptEmbeddingModel/data/data-concept-instance-relations.txt" 
file_path = "./../../data/ms_concept_graph/data-concept-instance-relations.txt"
data_df = pd.read_csv(file_path, header=None, names=["property", "concept", "num_relation"], sep="\t")

# %%
print ('Data After Loading MS Concept Graph')
data_df
# Out:
# Data After Loading MS Concept Graph
#                                  property  \
# 0                                  factor
# 1                 free rich company datum
# 2                 free rich company datum
# 3                                   state
# 4                              supplement
# ...                                   ...
# 33377315   popular legacy datum structure
# 33377316                   norwegian food
# 33377317                     freeze skill
# 33377318  enhanced enforcement initiative
# 33377319  enhanced enforcement initiative
#
#                                              concept  num_relation
# 0                                                age         35167
# 1                                               size         33222
# 2                                            revenue         33185
# 3                                         california         18062
# 4                            msm glucosamine sulfate         15942
# ...                                              ...           ...
# 33377315                          binary search tree             1
# 33377316                                       lefse             1
# 33377317                                     new fot             1
# 33377318  monthly impact inspections of problem mine             1
# 33377319           pattern of violation notification             1
#
# [33377320 rows x 3 columns]

# %%
data_df.sort_values('num_relation', ascending=False, inplace=True)

# %%
print ('Data After Sorting on Num Relation')
data_df
# Out:
# Data After Sorting on Num Relation
#                                  property                            concept  \
# 0                                  factor                                age
# 1                 free rich company datum                               size
# 2                 free rich company datum                            revenue
# 3                                   state                         california
# 4                              supplement            msm glucosamine sulfate
# ...                                   ...                                ...
# 18841597        permanent control measure                       straw wattle
# 18841596        permanent control measure                          check dam
# 18841595        permanent control measure                  vegetative buffer
# 18841594        permanent control measure                       ditch lining
# 33377319  enhanced enforcement initiative  pattern of violation notification
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
data_df = data_df[['concept', 'property', 'num_relation']]
data_df
# Out:
#                                     concept                         property  \
# 0                                       age                           factor
# 1                                      size          free rich company datum
# 2                                   revenue          free rich company datum
# 3                                california                            state
# 4                   msm glucosamine sulfate                       supplement
# ...                                     ...                              ...
# 18841597                       straw wattle        permanent control measure
# 18841596                          check dam        permanent control measure
# 18841595                  vegetative buffer        permanent control measure
# 18841594                       ditch lining        permanent control measure
# 33377319  pattern of violation notification  enhanced enforcement initiative
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
top_k = 15000

# %%
data_df = data_df[0:top_k]
print (f'Data Df after taking top {top_k} records \n:')
data_df
# Out:
# Data Df after taking top 15000 records
# :
#                        concept                   property  num_relation
# 0                          age                     factor         35167
# 1                         size    free rich company datum         33222
# 2                      revenue    free rich company datum         33185
# 3                   california                      state         18062
# 4      msm glucosamine sulfate                 supplement         15942
# ...                        ...                        ...           ...
# 15045                  dentist        health professional           191
# 15044              temperature    meteorological variable           191
# 15043                  toluene  volatile organic compound           191
# 15042                 football          competitive sport           191
# 15041                 medicaid        entitlement program           191
#
# [15000 rows x 3 columns]

# %%
unique_concept_list = data_df["concept"].unique()
np.random.shuffle(unique_concept_list)
print (unique_concept_list.shape[0])
print (type(unique_concept_list))
# Out:
# 6006
# <class 'numpy.ndarray'>

# %%
num_unique_concepts = len(unique_concept_list)
print ('Num Unique Positive Concepts:', num_unique_concepts)
# Out:
# Num Unique Positive Concepts: 6006

# %%
print (data_df["concept"].value_counts())
# Out:
# age                             71
# water                           52
# temperature                     52
# diabetes                        45
# education                       44
#                                 ..
# generalized anxiety disorder     1
# exxonmobil                       1
# genetic background               1
# family income                    1
# tree removal                     1
# Name: concept, Length: 6006, dtype: int64

# %%
train_ratio, val_ratio, test_ratio = 0.85, 0.10, 0.05

# %%
num_train_concepts = int(num_unique_concepts * train_ratio)
num_val_concepts = int(num_unique_concepts * val_ratio)
num_test_concepts = int(num_unique_concepts * test_ratio)

print (num_train_concepts)
print (num_val_concepts)
print (num_test_concepts)
# Out:
# 5105
# 600
# 300

# %%
train_concept = unique_concept_list[0:num_train_concepts]
valid_concept = unique_concept_list[num_train_concepts:num_train_concepts + num_val_concepts]
test_concept = unique_concept_list[num_train_concepts + num_val_concepts:]

print ('Number of Positive Train Concept :', len(train_concept))
print ('Number of Positive Valid Concept :', len(valid_concept))
print ('Number of Positive Test Concept :', len(test_concept))
# Out:
# Number of Positive Train Concept : 5105
# Number of Positive Valid Concept : 600
# Number of Positive Test Concept : 301

# %% [markdown]
# print ('\nTrain Concept :', *train_concept, sep=", ")
# print ('\nValid Concept :', *valid_concept, sep=", ")
# print ('\nTest Concept :', *test_concept, sep=", ")

# %%
print ('Total Number of Positive Concepts :', num_train_concepts + num_val_concepts + num_test_concepts)
# Out:
# Total Number of Positive Concepts : 6005

# %%
print ('+' * 50)

print ('Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap')
assert set (train_concept) != set (valid_concept)
assert set (train_concept) != set (test_concept)
assert set (valid_concept) != set (test_concept)

print ('Assertions Passed')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap
# Assertions Passed

# %%
train_df = data_df[data_df['concept'].isin(train_concept)]
valid_df = data_df[data_df['concept'].isin(valid_concept)]
test_df = data_df[data_df['concept'].isin(test_concept)]

print ('Number of Train Records :', len(train_df))
print ('Number of Valid Records :', len(valid_df))
print ('NUmber of Test Records :', len(test_df))

print ('+' * 50)
# Out:
# Number of Train Records : 12652
# Number of Valid Records : 1473
# NUmber of Test Records : 875
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
print ('\ncheck if train, val and test dataframes have any overlap')
df = train_df.merge(test_df, how = 'inner' ,indicator=False)
print('\n', df)

df = train_df.merge(valid_df, how = 'inner' ,indicator=False)
print('\n', df)

df = test_df.merge(valid_df, how = 'inner', indicator=False)
print('\n', df)
# Out:
# check if train, val and test dataframes have any overlap
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []

# %%
train_df = train_df.drop("num_relation", axis=1)

# %%
train_df.to_csv("mscg_new_pos_train.tsv", sep="\t", index=None, header=None)

# %%
valid_df = valid_df.drop("num_relation", axis=1)

# %%
valid_df.to_csv("mscg_new_pos_valid.tsv", sep="\t", index=None, header=None)

# %%
def generate_pos_neg_test_data(test_df):
    
    # print (test_df.head())
    
    test_df.reset_index(drop=True, inplace=True)
    test_df = test_df.drop("num_relation", axis=1)
    test_df["label"] = 1
    
    test_df.set_index("concept", drop=False)
    
    print (test_df.head())
    print (test_df.shape)
    
    unique_test_concept = test_df["concept"].unique()
    
    print (len(unique_test_concept))
    
    negative_data = []
    for concept in unique_test_concept:
        
        temp_df = test_df[test_df["concept"] != concept]
        
        # print ("temp_df")
        # print (temp_df)
        
        sampled_property = np.random.choice(temp_df["property"].unique(), size=5, replace=False)
        
        # print ("sampled_property")
        # print (sampled_property)
        
        negative_data.append([(concept, prop, 0) for prop in sampled_property])
    
    # print ("negative_data")
    # print (len(negative_data))
    # print (negative_data)
    
    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)

    print("negative_data_df")
    print (negative_data_df.shape)
    
    all_data = pd.concat([test_df, negative_data_df], ignore_index=True)
    
    print("All Data")
    print (all_data.shape)
    
    all_data= all_data.sample(frac=1)
    
    all_data.to_csv("mscg_new_pos_neg_test.tsv", sep="\t", header=None, index=None)
    
    all_data.set_index("concept", drop=False)
    
    for concept in all_data["concept"].unique():
        
        print ("Train Data -------------")
        print (train_df[train_df["concept"] == concept])
        print ("Test Data-----------")
        print (all_data[all_data["concept"] == concept])
        print ("++++++++++++++")
        print ()
    
generate_pos_neg_test_data(test_df)
# Out:
#      concept               property  label
# 0        age                 factor      1
# 1        age               variable      1
# 2  info trac  supplemental material      1
# 3      metal               material      1
# 4      glass               material      1
# (875, 3)
# 301
# negative_data_df
# (1505, 3)
# All Data
# (2380, 3)
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept              property  label
# 786       ox                animal      1
# 2254      ox             treatment      0
# 2252      ox              chemical      0
# 2250      ox                  name      0
# 2251      ox       large appliance      0
# 2253      ox  demographic question      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                    property  label
# 46    cereal                        food      1
# 293   cereal                        item      1
# 1036  cereal            imaging modality      0
# 1035  cereal         social network site      0
# 443   cereal                     product      1
# 416   cereal                        crop      1
# 660   cereal        complex carbohydrate      1
# 1037  cereal             diagnostic test      0
# 404   cereal                carbohydrate      1
# 1038  cereal           suitable material      0
# 418   cereal                starchy food      1
# 1039  cereal  demographic characteristic      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept                property  label
# 540   antibiotic               treatment      1
# 1042  antibiotic                document      0
# 50    antibiotic              medication      1
# 740   antibiotic                  factor      1
# 1041  antibiotic  mosquito borne disease      0
# 1044  antibiotic             hydrocarbon      0
# 1040  antibiotic         personal factor      0
# 1043  antibiotic            skin disease      0
# 239   antibiotic                medicine      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept         property  label
# 1816  antimony  utility service      0
# 1817  antimony      hydrocarbon      0
# 1818  antimony   public program      0
# 1815  antimony     skin problem      0
# 1819  antimony        procedure      0
# 473   antimony            metal      1
# 487   antimony          element      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#         concept                         property  label
# 112   newspaper               traditional medium      1
# 1059  newspaper     addiction treatment approach      0
# 151   newspaper                           source      1
# 731   newspaper                         resource      1
# 250   newspaper                      mass medium      1
# 1058  newspaper  gastrointestinal adverse effect      0
# 251   newspaper                         material      1
# 1055  newspaper                            brand      0
# 1057  newspaper                      simple carb      0
# 174   newspaper                             item      1
# 1056  newspaper                           medium      0
# 56    newspaper                           medium      1
# 651   newspaper                      publication      1
# 851   newspaper                     print medium      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                  concept                  property  label
# 2097  computer equipment                    region      0
# 2098  computer equipment          brittle material      0
# 672   computer equipment                 emergency      1
# 2096  computer equipment  confidential information      0
# 2099  computer equipment      demographic variable      0
# 2095  computer equipment                 flavonoid      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#         concept             property  label
# 1374  vitamin a          contaminant      0
# 277   vitamin a             nutrient      1
# 187   vitamin a              vitamin      1
# 528   vitamin a  fat soluble vitamin      1
# 1372  vitamin a         carbohydrate      0
# 1373  vitamin a         print medium      0
# 413   vitamin a          antioxidant      1
# 686   vitamin a        micronutrient      1
# 1370  vitamin a               aspect      0
# 1371  vitamin a        basic service      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                          property  label
# 70      age                         parameter      1
# 878     age            short chain fatty acid      0
# 25      age                 demographic datum      1
# 402     age                            aspect      1
# 654     age                              item      1
# ..      ...                               ...    ...
# 240     age                       host factor      1
# 865     age                  clinical feature      1
# 247     age                 prognostic factor      1
# 341     age  socio demographic characteristic      1
# 465     age                    account factor      1
#
# [76 rows x 3 columns]
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#               concept                 property  label
# 992  tensile strength  sociodemographic factor      0
# 34   tensile strength      mechanical property      1
# 994  tensile strength                   region      0
# 363  tensile strength        physical property      1
# 990  tensile strength              information      0
# 993  tensile strength            small portion      0
# 991  tensile strength                shellfish      0
# 206  tensile strength                 property      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept         property  label
# 1874   mcp 1     winter sport      0
# 1871   mcp 1             cost      0
# 512    mcp 1        chemokine      1
# 1870   mcp 1  basic criterion      0
# 1872   mcp 1       flavonoids      0
# 1873   mcp 1     oecd country      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#       concept             property  label
# 1156  hormone   autoimmune disease      0
# 1155  hormone          vital organ      0
# 1158  hormone  potassium rich food      0
# 94    hormone               factor      1
# 1157  hormone          insecticide      0
# 1159  hormone            emergency      0
# 667   hormone            substance      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                   concept                         property  label
# 1748  conflict resolution               corrosive material      0
# 429   conflict resolution                            topic      1
# 1747  conflict resolution     extracellular matrix protein      0
# 719   conflict resolution                            skill      1
# 1746  conflict resolution  sociodemographic characteristic      0
# 1745  conflict resolution               poor credit factor      0
# 1749  conflict resolution                         additive      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept               property  label
# 624   democrat          political tag      1
# 2029  democrat  inorganic contaminant      0
# 2026  democrat            simple carb      0
# 2025  democrat   relaxation technique      0
# 2028  democrat         mental illness      0
# 2027  democrat            carrier gas      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                         property  label
# 1905   thigh  post translational modification      0
# 1907   thigh                         variable      0
# 550    thigh                             area      1
# 1906   thigh                   imaging method      0
# 1909   thigh                        livestock      0
# 1908   thigh                         gemstone      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept       property  label
# 1489  benadryl       nutrient      0
# 1486  benadryl    simple carb      0
# 1485  benadryl       industry      0
# 236   benadryl  antihistamine      1
# 1487  benadryl  investigation      0
# 1488  benadryl         insect      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                     property  label
# 360    paint                     industry      1
# 41     paint                     material      1
# 354    paint                      coating      1
# 1019   paint                         tool      0
# 104    paint                      product      1
# 1018   paint                         fish      0
# 67     paint                         item      1
# 230    paint           hazardous material      1
# 434    paint                       medium      1
# 541    paint                    substance      1
# 407    paint                     chemical      1
# 1015   paint           confounding factor      0
# 1017   paint                 organization      0
# 1016   paint  over the counter painkiller      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                        property  label
# 22    argon                       inert gas      1
# 378   argon                       noble gas      1
# 951   argon                      ingredient      0
# 51    argon                             gas      1
# 639   argon                        rare gas      1
# 953   argon               demographic datum      0
# 950   argon                          flavor      0
# 623   argon                inert atmosphere      1
# 495   argon                     carrier gas      1
# 952   argon  popular social networking site      0
# 954   argon                         program      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept                      property  label
# 1076  motorola                     criterion      0
# 1077  motorola       demographic information      0
# 568   motorola                  manufacturer      1
# 216   motorola                 breed partner      1
# 62    motorola                       company      1
# 1075  motorola  gastrointestinal side effect      0
# 1078  motorola          demographic variable      0
# 1079  motorola                  organization      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept            property  label
# 2339     sle  social medium site      0
# 2335     sle            facility      0
# 838      sle  autoimmune disease      1
# 2337     sle             expense      0
# 2336     sle         host factor      0
# 2338     sle   peripheral device      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept           property  label
# 1685  burberry          chemokine      0
# 1686  burberry              theme      0
# 1687  burberry      basic amenity      0
# 1689  burberry           organism      0
# 352   burberry              brand      1
# 1688  burberry  medical treatment      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept            property  label
# 2245  promoter    natural material      0
# 2246  promoter             science      0
# 2247  promoter   essential service      0
# 784   promoter  regulatory element      1
# 2249  promoter          confounder      0
# 2248  promoter           character      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                    property  label
# 888   metal                  usb device      0
# 885   metal  neurodegenerative disorder      0
# 854   metal                     product      1
# 295   metal         conductive material      1
# 455   metal                   substance      1
# 887   metal                   oily fish      0
# 398   metal                        item      1
# 797   metal                      object      1
# 314   metal                 contaminant      1
# 193   metal                     surface      1
# 889   metal          inorganic material      0
# 7     metal       inorganic contaminant      1
# 271   metal                incompatible      1
# 542   metal              rigid material      1
# 405   metal                   substrate      1
# 707   metal                   commodity      1
# 385   metal                   pollutant      1
# 346   metal           suitable material      1
# 3     metal                    material      1
# 886   metal           prognostic factor      0
# 574   metal          inorganic material      1
# 436   metal                    industry      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept                       property  label
# 1698  san antonio                      chemokine      0
# 1699  san antonio                     discipline      0
# 1697  san antonio                       disorder      0
# 361   san antonio                           city      1
# 1696  san antonio                utility service      0
# 1695  san antonio  personal protective equipment      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                         concept              property  label
# 1521  bakersfield public record      control variable      0
# 1520  bakersfield public record       natural element      0
# 1523  bakersfield public record  protective equipment      0
# 261   bakersfield public record  valuable information      1
# 1522  bakersfield public record                 fruit      0
# 1524  bakersfield public record    withdrawal symptom      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept       property  label
# 2085  aluminum oxide  basic service      0
# 2088  aluminum oxide      vegetable      0
# 2087  aluminum oxide    information      0
# 2089  aluminum oxide  credit factor      0
# 666   aluminum oxide       material      1
# 2086  aluminum oxide    contaminant      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept               property  label
# 1737  alkalinity               province      0
# 1738  alkalinity              phagocyte      0
# 1736  alkalinity  extreme weather event      0
# 1739  alkalinity               nutrient      0
# 422   alkalinity              parameter      1
# 1735  alkalinity                  snack      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                 property  label
# 1767     fhm               antibiotic      0
# 1768     fhm  clinical characteristic      0
# 1769     fhm          negative factor      0
# 1765     fhm                     test      0
# 446      fhm                 magazine      1
# 1766     fhm              bakery item      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept              property  label
# 2230     emc      safety equipment      0
# 2234     emc       large appliance      0
# 2232     emc                  cell      0
# 2233     emc                  carb      0
# 2231     emc  commonwealth country      0
# 776      emc               company      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#       concept               property  label
# 1584  finnish                seafood      0
# 1581  finnish  complementary therapy      0
# 289   finnish               language      1
# 1580  finnish   transparent material      0
# 1583  finnish                  breed      0
# 1582  finnish       adverse reaction      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept         property  label
# 665    rayon  synthetic fiber      1
# 2084   rayon          product      0
# 2080   rayon         additive      0
# 2082   rayon            value      0
# 2083   rayon         property      0
# 2081   rayon           insect      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#       concept                        property  label
# 244   myspace                         website      1
# 1097  myspace                        resource      0
# 811   myspace                   social medium      1
# 1098  myspace                    member state      0
# 225   myspace                  social network      1
# 1099  myspace               demographic datum      0
# 1095  myspace                    skin disease      0
# 648   myspace             social network site      1
# 688   myspace              social medium site      1
# 1096  myspace                        magazine      0
# 71    myspace                            site      1
# 589   myspace  popular social networking site      1
# 97    myspace          social networking site      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
# ...
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept               property  label
# 2    info trac  supplemental material      1
# 884  info trac                  snack      0
# 880  info trac                  organ      0
# 883  info trac        terrible factor      0
# 881  info trac          basic amenity      0
# 882  info trac   hard or sharp object      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                  property  label
# 2078  batman  gastrointestinal symptom      0
# 2076  batman                      cell      0
# 2077  batman                polyacetal      0
# 659   batman                 character      1
# 2075  batman           sensitive datum      0
# 2079  batman              print medium      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#         concept                    property  label
# 1793  carnation                   noble gas      0
# 461   carnation                      flower      1
# 1790  carnation  demographic characteristic      0
# 1792  carnation        vector borne disease      0
# 1791  carnation         firm characteristic      0
# 1794  carnation                  ingredient      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept              property  label
# 631    radar            technology      1
# 1773   radar              variable      0
# 1770   radar             phagocyte      0
# 1772   radar          organic acid      0
# 449    radar           application      1
# 1774   radar     simple painkiller      0
# 469    radar                sensor      1
# 1771   radar  small financial cost      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                    concept                                 property  label
# 1961  system administrator                                    input      0
# 1964  system administrator                       poor credit factor      0
# 1963  system administrator  financial aspect of product development      0
# 1960  system administrator                  gastrointestinal effect      0
# 1962  system administrator                                    field      0
# 586   system administrator                                     user      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept           property  label
# 1842  rowing             staple      0
# 1840  rowing         antibiotic      0
# 1841  rowing  peripheral device      0
# 484   rowing              sport      1
# 1843  rowing      social factor      0
# 835   rowing           activity      1
# 1844  rowing      monetary cost      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept               property  label
# 2311   sound    domesticated animal      0
# 821    sound                  topic      1
# 2312   sound                  fruit      0
# 2310   sound  inorganic contaminant      0
# 2314   sound               activity      0
# 2313   sound                  issue      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#               concept                property  label
# 2158  zoledronic acid           antihistamine      0
# 2159  zoledronic acid            organization      0
# 715   zoledronic acid          bisphosphonate      1
# 2155  zoledronic acid           consideration      0
# 2156  zoledronic acid               phagocyte      0
# 2157  zoledronic acid  patient related factor      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                        property  label
# 2319   rifle  popular social networking site      0
# 2316   rifle                physical symptom      0
# 2315   rifle                monetary expense      0
# 2317   rifle     intellectual property right      0
# 2318   rifle                        question      0
# 823    rifle                         firearm      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept                     property  label
# 674   paracetamol             simple analgesic      1
# 306   paracetamol  over the counter painkiller      1
# 73    paracetamol                   painkiller      1
# 635   paracetamol                    analgesic      1
# 1105  paracetamol                 jurisdiction      0
# 742   paracetamol                     medicine      1
# 1108  paracetamol                       legume      0
# 1106  paracetamol                  poor factor      0
# 524   paracetamol            simple painkiller      1
# 1109  paracetamol               financial cost      0
# 1107  paracetamol                      quality      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept               property  label
# 1112    utah    mechanical property      0
# 74      utah                  state      1
# 1113    utah  descriptive statistic      0
# 1114    utah     withdrawal symptom      0
# 1110    utah        negative factor      0
# 1111    utah      essential service      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                         concept             property  label
# 1383  low tire pressure warning    biological factor      0
# 1380  low tire pressure warning  patient information      0
# 189   low tire pressure warning              feature      1
# 1384  low tire pressure warning                topic      0
# 1382  low tire pressure warning   regulatory element      0
# 1381  low tire pressure warning       local material      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                       concept                        property  label
# 2221  credit card information                  local material      0
# 773   credit card information           sensitive information      1
# 2220  credit card information  sensitive personal information      0
# 2224  credit card information             patient demographic      0
# 2223  credit card information      socio demographic variable      0
# 2222  credit card information                   ace inhibitor      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept                 property  label
# 1536  paclitaxel     demographic variable      0
# 1537  paclitaxel  socio demographic datum      0
# 1535  paclitaxel                    topic      0
# 1538  paclitaxel     communicable disease      0
# 266   paclitaxel                   taxane      1
# 1539  paclitaxel  gastrointestinal effect      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                   concept           property  label
# 1214  geographic location    cold water fish      0
# 113   geographic location             factor      1
# 1212  geographic location    synthetic fiber      0
# 1213  geographic location              event      0
# 1210  geographic location  essential service      0
# 1211  geographic location               word      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                  property  label
# 1845      ip  english speaking country      0
# 1849      ip                   symptom      0
# 1847      ip       household appliance      0
# 1848      ip            clinical datum      0
# 489       ip                  protocol      1
# 1846      ip         suitable material      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#             concept               property  label
# 1895  social phobia              substance      0
# 1898  social phobia            institution      0
# 1897  social phobia               flavonol      0
# 532   social phobia       anxiety disorder      1
# 1899  social phobia            insecticide      0
# 1896  social phobia  common hotel facility      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept                 property  label
# 1412  doxycycline       clinical parameter      0
# 1411  doxycycline        magnetic property      0
# 1414  doxycycline       agricultural input      0
# 1413  doxycycline                     item      0
# 1410  doxycycline  demographic information      0
# 205   doxycycline               antibiotic      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept          property  label
# 1795     fur        polyacetal      0
# 1798     fur             skill      0
# 466      fur              item      1
# 1799     fur           feature      0
# 1797     fur  intangible asset      0
# 1796     fur  safety equipment      0
# ++++++++++++++

# %%
# !pwd
# Out:
# /home/amitgajbhiye/cardiff_work/siamese_concept_property/notebooks

# %%
train_df.dtypes

# %%
def generate_negative_data(data_df, num_neg_pair=1):
    
    data_df.reset_index(drop=True, inplace=True)
    
    #print ('data_df.index :',data_df.index)
        
    negative_data = []
    
    concept_list = data_df['concept'].unique()

    for concept in concept_list:
        
        negative_data_for_concept = []

        positive_data = data_df[data_df["concept"] == concept]
        #positive_data_index = data_df[data_df["concept"] == concept].index
        positive_data_index = np.array(positive_data.index)
        num_positive_data = len(positive_data_index)

        rest_df = data_df.drop(positive_data_index)
        rest_df.reset_index(drop=True, inplace=True)
        rest_df_idx = rest_df.index
        
        pos_or_negative = np.random.choice(['neg_concept', 'neg_property'], size=len(positive_data_index))
        
        num_neg_concept = Counter(pos_or_negative).get('neg_concept')
        num_neg_property = Counter(pos_or_negative).get('neg_property')
                
        print ('\n')
        print ('--' * 50 )
        print ('Concept :', concept)
        print ('len(positive_data):', len(positive_data))
        print ('num_neg_concept :',  num_neg_concept)
        print ('num_neg_property :', num_neg_property)
        print ('postitive_data_index :', positive_data_index)
        print ('\npositive_data:')
        print (positive_data)
        
        neg_concept_data = []
        neg_property_data = []
        
        
        # indexes of the records for which concept will be corrupted.
        if num_neg_concept is not None:
            
            neg_concept_record_idx = np.random.choice(positive_data_index, size=num_neg_concept)
            neg_concept = rest_df.sample(n = num_neg_pair * num_neg_concept)['concept'].to_numpy()
            neg_concept_split = np.split(neg_concept, len(neg_concept_record_idx))
            
            print ('\nneg_concepts')
            print (neg_concept)
            
            for array, idx in zip(neg_concept_split, neg_concept_record_idx):
                neg_concept_data.extend([(con, positive_data.loc[idx]['property'], 0) for con in array])                
        else:
            print ('num_neg_concept in None')
            neg_concept_record_idx = []
        
        print ('Negative concept for true property')
        print (neg_concept_data)

                
        if num_neg_property is not None:
            
            # indexes of the records for which property will be corrupted.
            #neg_property_record_idx = np.array([idx for idx in positive_data_index if idx not in neg_concept_record_idx])
            
            neg_property = rest_df.sample(n=num_neg_pair * num_neg_property)['property'].to_list()
            print ('\nneg_property :', neg_property)
            
            neg_property_data.extend([(concept, neg_prop, 0) for neg_prop in neg_property])
            
        print ('Negative Property data for true Concept :')
        print (neg_property_data)
            
        negative_data_for_concept.extend(neg_concept_data)
        negative_data_for_concept.extend(neg_property_data)
        
        print ('\nNumber of Negative Data For Concept :', len(negative_data_for_concept))
        print ('negative_data_for_concept:')
        print (negative_data_for_concept)
        
        negative_data.append(negative_data_for_concept)
        

    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)
    
    
    all_data = pd.concat([data_df, negative_data_df], ignore_index=True)
    
    all_data = all_data.sample(frac=1)
    all_data.drop_duplicates(inplace=True)
    
    print ('\nFinished Generating Data For One Set')
    print ('len(all_data) :', len(all_data))
    
    return all_data

# %%
print ('#' * 50)
print ('Generating Negative Train Data')

# %%
print ('\n Training Data')

# %%
pos_neg_train_df = generate_negative_data(train_df, num_neg_pair=num_neg_pair)
pos_neg_train_df.to_csv('data/65k_train_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Train Record Before Negative Data:', len(train_df))
print ('Train Record After Negative Data:', len(pos_neg_train_df))

# %%
print ('#' * 50)
print ('Generating Negative Valid Data')
print ('\n Validation Data')
pos_neg_val_df = generate_negative_data(valid_df, num_neg_pair=num_neg_pair)
pos_neg_val_df.to_csv('data/65k_valid_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Validation Record Before Negative Data:', len(valid_df))
print ('Validation Record After Negative Data:', len(pos_neg_val_df))

# %%
print ('#' * 50)
print ('Generating Negative Test Data')

print ('\n Test Data')
pos_neg_test_df = generate_negative_data(test_df, num_neg_pair=num_neg_pair)
pos_neg_test_df.to_csv('data/65k_test_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Test Record Before Negative Data:', len(test_df))
print ('Test Record After Negative Data:', len(pos_neg_test_df))
