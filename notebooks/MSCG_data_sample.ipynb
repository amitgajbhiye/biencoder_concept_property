# %%
import torch
import pandas as pd
import numpy as np

from collections import Counter

# %%
#file_path = "/scratch/c.scmag3/conceptEmbeddingModel/data/data-concept-instance-relations.txt" 
file_path = "./../../data/ms_concept_graph/data-concept-instance-relations.txt"
data_df = pd.read_csv(file_path, header=None, names=["property", "concept", "num_relation"], sep="\t")

# %%
print ('Data After Loading MS Concept Graph')
data_df
# Out:
# Data After Loading MS Concept Graph
#                                  property  \
# 0                                  factor
# 1                 free rich company datum
# 2                 free rich company datum
# 3                                   state
# 4                              supplement
# ...                                   ...
# 33377315   popular legacy datum structure
# 33377316                   norwegian food
# 33377317                     freeze skill
# 33377318  enhanced enforcement initiative
# 33377319  enhanced enforcement initiative
#
#                                              concept  num_relation
# 0                                                age         35167
# 1                                               size         33222
# 2                                            revenue         33185
# 3                                         california         18062
# 4                            msm glucosamine sulfate         15942
# ...                                              ...           ...
# 33377315                          binary search tree             1
# 33377316                                       lefse             1
# 33377317                                     new fot             1
# 33377318  monthly impact inspections of problem mine             1
# 33377319           pattern of violation notification             1
#
# [33377320 rows x 3 columns]

# %%
data_df.sort_values('num_relation', ascending=False, inplace=True)

# %%
print ('Data After Sorting on Num Relation')
data_df
# Out:
# Data After Sorting on Num Relation
#                                  property                            concept  \
# 0                                  factor                                age
# 1                 free rich company datum                               size
# 2                 free rich company datum                            revenue
# 3                                   state                         california
# 4                              supplement            msm glucosamine sulfate
# ...                                   ...                                ...
# 18841597        permanent control measure                       straw wattle
# 18841596        permanent control measure                          check dam
# 18841595        permanent control measure                  vegetative buffer
# 18841594        permanent control measure                       ditch lining
# 33377319  enhanced enforcement initiative  pattern of violation notification
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
data_df = data_df[['concept', 'property', 'num_relation']]
data_df
# Out:
#                                     concept                         property  \
# 0                                       age                           factor
# 1                                      size          free rich company datum
# 2                                   revenue          free rich company datum
# 3                                california                            state
# 4                   msm glucosamine sulfate                       supplement
# ...                                     ...                              ...
# 18841597                       straw wattle        permanent control measure
# 18841596                          check dam        permanent control measure
# 18841595                  vegetative buffer        permanent control measure
# 18841594                       ditch lining        permanent control measure
# 33377319  pattern of violation notification  enhanced enforcement initiative
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
data_df =

# %%
top_k = 15000

# %%
data_df = data_df[0:top_k]
print (f'Data Df after taking top {top_k} records \n:')
data_df
# Out:
# Data Df after taking top 15000 records
# :
#                        concept                   property  num_relation
# 0                          age                     factor         35167
# 1                         size    free rich company datum         33222
# 2                      revenue    free rich company datum         33185
# 3                   california                      state         18062
# 4      msm glucosamine sulfate                 supplement         15942
# ...                        ...                        ...           ...
# 15045                  dentist        health professional           191
# 15044              temperature    meteorological variable           191
# 15043                  toluene  volatile organic compound           191
# 15042                 football          competitive sport           191
# 15041                 medicaid        entitlement program           191
#
# [15000 rows x 3 columns]

# %%
unique_concept_list = data_df["concept"].unique()
np.random.shuffle(unique_concept_list)
print (unique_concept_list.shape[0])
print (type(unique_concept_list))
# Out:
# 6006
# <class 'numpy.ndarray'>

# %%
num_unique_concepts = len(unique_concept_list)
print ('Num Unique Positive Concepts:', num_unique_concepts)
# Out:
# Num Unique Positive Concepts: 6006

# %%
print (data_df["concept"].value_counts())
# Out:
# age                             71
# water                           52
# temperature                     52
# diabetes                        45
# education                       44
#                                 ..
# generalized anxiety disorder     1
# exxonmobil                       1
# genetic background               1
# family income                    1
# tree removal                     1
# Name: concept, Length: 6006, dtype: int64

# %%
train_ratio, val_ratio, test_ratio = 0.85, 0.10, 0.05

# %%
num_train_concepts = int(num_unique_concepts * train_ratio)
num_val_concepts = int(num_unique_concepts * val_ratio)
num_test_concepts = int(num_unique_concepts * test_ratio)

print (num_train_concepts)
print (num_val_concepts)
print (num_test_concepts)
# Out:
# 5105
# 600
# 300

# %%
train_concept = unique_concept_list[0:num_train_concepts]
valid_concept = unique_concept_list[num_train_concepts:num_train_concepts + num_val_concepts]
test_concept = unique_concept_list[num_train_concepts + num_val_concepts:]

print ('Number of Positive Train Concept :', len(train_concept))
print ('Number of Positive Valid Concept :', len(valid_concept))
print ('Number of Positive Test Concept :', len(test_concept))
# Out:
# Number of Positive Train Concept : 5105
# Number of Positive Valid Concept : 600
# Number of Positive Test Concept : 301

# %% [markdown]
# print ('\nTrain Concept :', *train_concept, sep=", ")
# print ('\nValid Concept :', *valid_concept, sep=", ")
# print ('\nTest Concept :', *test_concept, sep=", ")

# %%
print ('Total Number of Positive Concepts :', num_train_concepts + num_val_concepts + num_test_concepts)
# Out:
# Total Number of Positive Concepts : 6005

# %%
print ('+' * 50)

print ('Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap')
assert set (train_concept) != set (valid_concept)
assert set (train_concept) != set (test_concept)
assert set (valid_concept) != set (test_concept)

print ('Assertions Passed')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap
# Assertions Passed

# %%
train_df = data_df[data_df['concept'].isin(train_concept)]
valid_df = data_df[data_df['concept'].isin(valid_concept)]
test_df = data_df[data_df['concept'].isin(test_concept)]

print ('Number of Train Records :', len(train_df))
print ('Number of Valid Records :', len(valid_df))
print ('NUmber of Test Records :', len(test_df))

print ('+' * 50)
# Out:
# Number of Train Records : 12854
# Number of Valid Records : 1465
# NUmber of Test Records : 681
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
print ('\ncheck if train, val and test dataframes have any overlap')
df = train_df.merge(test_df, how = 'inner' ,indicator=False)
print('\n', df)

df = train_df.merge(valid_df, how = 'inner' ,indicator=False)
print('\n', df)

df = test_df.merge(valid_df, how = 'inner', indicator=False)
print('\n', df)
# Out:
# check if train, val and test dataframes have any overlap
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []

# %%
train_df = train_df.drop("num_relation", axis=1)

# %%
train_df.to_csv("mscg_new_pos_train.tsv", sep="\t", index=None, header=None)

# %%
valid_df = valid_df.drop("num_relation", axis=1)

# %%
valid_df.to_csv("mscg_new_pos_valid.tsv", sep="\t", index=None, header=None)

# %%
test_df = test_df.drop("num_relation", axis=1)

# %%
def generate_pos_neg_test_data(test_df):
    
    # print (test_df.head())
    
    test_df.reset_index(drop=True, inplace=True)
    test_df = test_df.drop("num_relation", axis=1)
    test_df["label"] = 1
    
    test_df.set_index("concept", drop=False)
    
    print (test_df.head())
    print (test_df.shape)
    
    unique_test_concept = test_df["concept"].unique()
    
    print (len(unique_test_concept))
    
    negative_data = []
    for concept in unique_test_concept:
        
        temp_df = test_df[test_df["concept"] != concept]
        
        # print ("temp_df")
        # print (temp_df)
        
        sampled_property = np.random.choice(temp_df["property"].unique(), size=5, replace=False)
        
        # print ("sampled_property")
        # print (sampled_property)
        
        negative_data.append([(concept, prop, 0) for prop in sampled_property])
    
    # print ("negative_data")
    # print (len(negative_data))
    # print (negative_data)
    
    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)

    print("negative_data_df")
    print (negative_data_df.shape)
    
    all_data = pd.concat([test_df, negative_data_df], ignore_index=True)
    
    print("All Data")
    print (all_data.shape)
    
    all_data= all_data.sample(frac=1)
    
    all_data.to_csv("mscg_new_pos_neg_test.tsv", sep="\t", header=None, index=None)
    
    all_data.set_index("concept", drop=False)
    
    for concept in all_data["concept"].unique():
        
        print ("Train Data -------------")
        print (train_df[train_df["concept"] == concept])
        print ("Test Data-----------")
        print (all_data[all_data["concept"] == concept])
        print ("++++++++++++++")
        print ()
    
    return all_data
    
test_pos_neg_data = generate_pos_neg_test_data(test_df)
# Out:
#        concept               property  label
# 0  access code  supplemental material      1
# 1         cost                 factor      1
# 2    vegetable                   food      1
# 3       nickel                  metal      1
# 4         date            information      1
# (681, 3)
# 301
# negative_data_df
# (1505, 3)
# All Data
# (2186, 3)
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                concept            property  label
# 1951  nucleating agent       ace inhibitor      0
# 1952  nucleating agent              device      0
# 1954  nucleating agent  performance metric      0
# 1953  nucleating agent             browser      0
# 556   nucleating agent            additive      1
# 1955  nucleating agent           food item      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#            concept                property  label
# 1707  water supply  small monetary expense      0
# 440   water supply                 service      1
# 1709  water supply                material      0
# 1706  water supply      hazardous material      0
# 1710  water supply                property      0
# 1708  water supply                 vitamin      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept          property  label
# 898   hotel      healthy food      0
# 899   hotel       hydrocarbon      0
# 241   hotel            sector      1
# 565   hotel          location      1
# 896   hotel            entity      0
# 900   hotel   scented product      0
# 59    hotel          business      1
# 219   hotel           service      1
# 897   hotel  thermal property      0
# 163   hotel             place      1
# 210   hotel          industry      1
# 244   hotel          building      1
# 655   hotel      public place      1
# 475   hotel          supplier      1
# 550   hotel     establishment      1
# 257   hotel          facility      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept          property  label
# 152   forest         ecosystem      1
# 1016  forest              tool      0
# 1019  forest  alloying element      0
# 106   forest  natural resource      1
# 1017  forest     plant hormone      0
# 516   forest              area      1
# 1020  forest               tax      0
# 310   forest          resource      1
# 1018  forest        discipline      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept          property  label
# 1179  typewriter     violent crime      0
# 1180  typewriter      natural food      0
# 1178  typewriter       publication      0
# 1176  typewriter         substance      0
# 1177  typewriter          industry      0
# 534   typewriter    office machine      1
# 159   typewriter  office equipment      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept             property  label
# 1663  thermistor             evidence      0
# 1664  thermistor           embodiment      0
# 1661  thermistor           discipline      0
# 1662  thermistor        warranty term      0
# 415   thermistor   temperature sensor      1
# 1665  thermistor  online auction site      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                    property  label
# 911   drill                   appliance      0
# 913   drill                      factor      0
# 914   drill             optical element      0
# 322   drill                  power tool      1
# 915   drill  polymer composite material      0
# 67    drill                        tool      1
# 912   drill                     economy      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept      property  label
# 169   supervisory        device      1
# 1204  supervisory   hydrocarbon      0
# 1201  supervisory          bird      0
# 1203  supervisory       problem      0
# 1202  supervisory       surface      0
# 1205  supervisory  public place      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept            property  label
# 1489  inequality  polyhydric alcohol      0
# 329   inequality               issue      1
# 1487  inequality               issue      0
# 1490  inequality                 oil      0
# 1488  inequality               genre      0
# 1486  inequality          ingredient      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept    property  label
# 653    tesla     company      1
# 2126   tesla  profession      0
# 2127   tesla   operation      0
# 2128   tesla    magazine      0
# 2130   tesla         oil      0
# 2129   tesla     offense      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                property  label
# 1896     pda       medical condition      0
# 1899     pda                    game      0
# 1897     pda                   green      0
# 577      pda                  device      1
# 533      pda           mobile device      1
# 1898     pda           micronutrient      0
# 1900     pda  small monetary expense      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept           property  label
# 1741  goldenseal  optical component      0
# 1742  goldenseal          treatment      0
# 1743  goldenseal            setting      0
# 449   goldenseal               herb      1
# 1745  goldenseal            project      0
# 1744  goldenseal     office machine      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept              property  label
# 83     city          municipality      1
# 432    city      local government      1
# 424    city                  area      1
# 315    city           information      1
# 963    city         monetary cost      0
# 964    city          member state      0
# 962    city     glycosaminoglycan      0
# 961    city           risk factor      0
# 390    city      adding new input      1
# 965    city  vector borne disease      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept        property  label
# 1939   pinto    manufacturer      0
# 1936   pinto           state      0
# 1937   pinto   trace element      0
# 1938   pinto     electrolyte      0
# 1940   pinto  fermented food      0
# 549    pinto            bean      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept                   property  label
# 714  towing warranty  standard office equipment      0
# 713  towing warranty         performance metric      0
# 711  towing warranty             natural fabric      0
# 6    towing warranty              warranty term      1
# 712  towing warranty              mobile device      0
# 715  towing warranty               hard surface      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                   property  label
# 87     kiwi                      fruit      1
# 977    kiwi                        oil      0
# 979    kiwi  international credit card      0
# 978    kiwi     reactive oxygen specie      0
# 980    kiwi                     nation      0
# 976    kiwi                  condition      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept            property  label
# 1411   bonus   glycosaminoglycan      0
# 1413   bonus              cation      0
# 289    bonus             benefit      1
# 1412   bonus              defect      0
# 1415   bonus          fatty acid      0
# 1414   bonus  performance metric      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept                property  label
# 262   clarithromycin               macrolide      1
# 1376  clarithromycin                building      0
# 1377  clarithromycin  ferromagnetic material      0
# 1380  clarithromycin      autoimmune disease      0
# 1378  clarithromycin          social problem      0
# 1379  clarithromycin                    item      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept                 property  label
# 637   gibberellin            plant hormone      1
# 2102  gibberellin  educational institution      0
# 2101  gibberellin      entitlement program      0
# 2105  gibberellin                 designer      0
# 2104  gibberellin            consideration      0
# 2103  gibberellin            warranty term      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept          property  label
# 72      joy           emotion      1
# 928     joy            colour      0
# 926     joy          headache      0
# 535     joy           feeling      1
# 927     joy   optical element      0
# 929     joy      service club      0
# 227     joy  positive emotion      1
# 930     joy       alkyl group      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                concept           property  label
# 526   basketball court            amenity      1
# 1879  basketball court          advantage      0
# 1880  basketball court            product      0
# 1878  basketball court  essential mineral      0
# 1877  basketball court      natural fiber      0
# 1876  basketball court            amenity      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept     property  label
# 324  history        field      1
# 536  history        issue      1
# 172  history       factor      1
# 641  history       aspect      1
# 422  history       course      1
# 482  history  information      1
# 741  history    ecosystem      0
# 743  history     catalyst      0
# 368  history         area      1
# 90   history        topic      1
# 13   history      subject      1
# 68   history   discipline      1
# 745  history     language      0
# 744  history      offense      0
# 742  history       factor      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#       concept              property  label
# 1256  rosacea                entity      0
# 525   rosacea             condition      1
# 1259  rosacea        characteristic      0
# 1257  rosacea               keyword      0
# 1258  rosacea  small financial cost      0
# 1260  rosacea                  item      0
# 197   rosacea        skin condition      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                concept        property  label
# 1427  language barrier   monetary cost      0
# 1429  language barrier       infection      0
# 1428  language barrier        chemical      0
# 1430  language barrier  financial cost      0
# 295   language barrier          factor      1
# 1426  language barrier           green      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#         concept       property  label
# 851  tamil nadu          field      0
# 854  tamil nadu     cool color      0
# 853  tamil nadu  catecholamine      0
# 47   tamil nadu          state      1
# 855  tamil nadu   organization      0
# 852  tamil nadu          state      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#       concept             property  label
# 2184  slipper           medication      0
# 2181  slipper              meeting      0
# 2183  slipper  entitlement program      0
# 2185  slipper             designer      0
# 2182  slipper        mobile device      0
# 678   slipper       modern comfort      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept           property  label
# 1255    lens     gaming machine      0
# 387     lens  optical component      1
# 1254    lens              grain      0
# 1251    lens     modern comfort      0
# 196     lens    optical element      1
# 1252    lens           magazine      0
# 1253    lens             source      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept          property  label
# 65   mozilla firefox       web browser      1
# 799  mozilla firefox     family member      0
# 800  mozilla firefox        discipline      0
# 29   mozilla firefox           browser      1
# 540  mozilla firefox    modern browser      1
# 796  mozilla firefox  monetary expense      0
# 522  mozilla firefox  internet browser      1
# 798  mozilla firefox             state      0
# 797  mozilla firefox             image      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept         property  label
# 1065  catering         medicine      0
# 123   catering          service      1
# 1062  catering          barrier      0
# 1064  catering        appliance      0
# 1063  catering             site      0
# 1061  catering  fiber rich food      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#            concept         property  label
# 2154  binge eating          project      0
# 2152  binge eating    anticoagulant      0
# 664   binge eating  eating disorder      1
# 2155  binge eating  scented product      0
# 2153  binge eating    output device      0
# 2151  binge eating         variable      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      conc
1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                 concept            property  label
# 2037  facsimile machine             problem      0
# 2040  facsimile machine              fabric      0
# 598   facsimile machine    office equipment      1
# 2036  facsimile machine  reaction condition      0
# 2038  facsimile machine     public building      0
# 2039  facsimile machine           macrolide      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept                                   property  label
# 1990  inheritance                                       fish      0
# 1989  inheritance                                      image      0
# 1986  inheritance  server log record statistical information      0
# 571   inheritance                                    concept      1
# 1987  inheritance                                 vital sign      0
# 1988  inheritance                          medical condition      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#       concept            property  label
# 883  numbness  government program      0
# 55   numbness             symptom      1
# 884  numbness               place      0
# 881  numbness  hazardous material      0
# 885  numbness          constraint      0
# 882  numbness        video format      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                 property  label
# 300    cost                parameter      1
# 198    cost                   reason      1
# 209    cost                  barrier      1
# 687    cost                     rock      0
# 560    cost                  problem      1
# 100    cost              information      1
# 689    cost                   cation      0
# 688    cost                  problem      0
# 686    cost             natural food      0
# 176    cost                criterion      1
# 22     cost                    issue      1
# 450    cost  practical consideration      1
# 1      cost                   factor      1
# 92     cost            consideration      1
# 417    cost                 variable      1
# 352    cost               constraint      1
# 690    cost           public program      0
# 240    cost                   aspect      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#        concept       property  label
# 1160  charcoal           meal      0
# 151   charcoal         medium      1
# 1159  charcoal       relative      0
# 400   charcoal       material      1
# 1157  charcoal  plant hormone      0
# 1156  charcoal        browser      0
# 1158  charcoal  organic mulch      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                  property  label
# 508  pollen         airborne allergen      1
# 893  pollen  eastern european country      0
# 894  pollen              starchy food      0
# 892  pollen                 food item      0
# 679  pollen                 substance      1
# 895  pollen                   economy      0
# 57   pollen                  allergen      1
# 446  pollen                  particle      1
# 891  pollen                    colour      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept           property  label
# 1775  multiplication             region      0
# 1774  multiplication  medical condition      0
# 1773  multiplication           compound      0
# 467   multiplication          operation      1
# 1772  multiplication         embodiment      0
# 1771  multiplication          condition      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#             concept                 property  label
# 379  blood pressure              risk factor      1
# 619  blood pressure                 variable      1
# 933  blood pressure                cash crop      0
# 512  blood pressure  physiological parameter      1
# 931  blood pressure              heavy metal      0
# 934  blood pressure                     herb      0
# 935  blood pressure                    goods      0
# 530  blood pressure   physiological variable      1
# 293  blood pressure                parameter      1
# 205  blood pressure                   factor      1
# 74   blood pressure               vital sign      1
# 932  blood pressure           small molecule      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept       property  label
# 555    cocoa        product      1
# 1669   cocoa     cool color      0
# 468    cocoa           crop      1
# 1667   cocoa          alkyl      0
# 1668   cocoa  micronutrient      0
# 1666   cocoa   organic acid      0
# 1670   cocoa          image      0
# 420    cocoa      cash crop      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept                       property  label
# 1232  sleep apnea                     power tool      0
# 1235  sleep apnea                  monetary cost      0
# 1231  sleep apnea  personal protective equipment      0
# 1233  sleep apnea                           meat      0
# 185   sleep apnea                 sleep disorder      1
# 1234  sleep apnea                        economy      0
# 195   sleep apnea                       disorder      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept               property  label
# 684  access code               protocol      0
# 683  access code            alkyl group      0
# 682  access code      airborne allergen      0
# 681  access code           hard surface      0
# 0    access code  supplemental material      1
# 685  access code             fatty acid      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept           property  label
# 834  unemployment           compound      0
# 835  unemployment      vegetable oil      0
# 154  unemployment            problem      1
# 521  unemployment     social problem      1
# 831  unemployment         medication      0
# 833  unemployment          emergency      0
# 43   unemployment             factor      1
# 58   unemployment              issue      1
# 832  unemployment  electronic device      0
# 620  unemployment          condition      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#     concept                                   property  label
# 266    time                                    concept      1
# 362    time                                    element      1
# 725    time                                  humectant      0
# 461    time                                    barrier      1
# 563    time                                     aspect      1
# 108    time                                      datum      1
# 276    time                                   magazine      1
# 722    time                             skin condition      0
# 723    time                                     client      0
# 517    time                                publication      1
# 168    time                                      issue      1
# 189    time                                 constraint      1
# 32     time                                  parameter      1
# 8      time                                information      1
# 552    time                                  condition      1
# 724    time                                    project      0
# 721    time                             hdac inhibitor      0
# 438    time                         reaction parameter      1
# 477    time                         reaction condition      1
# 9      time                                     factor      1
# 648    time  server log record statistical information      1
# 394    time                                       item      1
# 631    time                                      topic      1
# 37     time                                   resource      1
# 146    time                                   variable      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept                                   property  label
# 1576   quail                                  cash crop      0
# 1577   quail  server log record statistical information      0
# 370    quail                                       bird      1
# 1579   quail                                office duty      0
# 1580   quail                           negative emotion      0
# 1578   quail                                    website      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept          property  label
# 819  denmark       marketplace      0
# 385  denmark            nation      1
# 671  denmark    nordic country      1
# 816  denmark          magazine      0
# 38   denmark  european country      1
# 247  denmark      member state      1
# 817  denmark    fermented food      0
# 818  denmark     alkyl radical      0
# 820  denmark            fabric      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept          property  label
# 2180  hydroxyzine     output device      0
# 2178  hydroxyzine   high-fiber food      0
# 2176  hydroxyzine              crop      0
# 677   hydroxyzine     antihistamine      1
# 2177  hydroxyzine         condition      0
# 2179  hydroxyzine  transition metal      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#           concept             property  label
# 643   fresh fruit        healthy snack      1
# 1103  fresh fruit        micronutrient      0
# 135   fresh fruit                 food      1
# 1105  fresh fruit      scented product      0
# 1102  fresh fruit  mechanical property      0
# 1101  fresh fruit        organic mulch      0
# 1104  fresh fruit       natural fabric      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#            concept                      property  label
# 2106  sober living                  organic acid      0
# ...
# 811  geography   electronic device      0
# 303  geography          discipline      1
# 813  geography               sense      0
# 34   geography             subject      1
# 814  geography  corrosive material      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept         property  label
# 2162  healthy eating      institution      0
# 666   healthy eating            topic      1
# 2164  healthy eating          keyword      0
# 2165  healthy eating    output device      0
# 2161  healthy eating          emotion      0
# 2163  healthy eating  public building      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#         concept            property  label
# 1512  wood chip  qualitative method      0
# 488   wood chip            material      1
# 1511  wood chip           vegetable      0
# 1515  wood chip   essential mineral      0
# 1513  wood chip               metal      0
# 1514  wood chip               green      0
# 339   wood chip       organic mulch      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#          concept                property  label
# 1293  production                  insect      0
# 212   production                activity      1
# 1294  production    complex carbohydrate      0
# 232   production              department      1
# 1291  production  physiological variable      0
# 419   production                    area      1
# 1292  production           monetary cost      0
# 626   production                  factor      1
# 1295  production        negative emotion      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#      concept           property  label
# 1023    pulp  financial expense      0
# 1025    pulp           building      0
# 1021    pulp            meeting      0
# 1022    pulp          macrolide      0
# 1024    pulp            feature      0
# 111     pulp           industry      1
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#              concept         property  label
# 568   glucocorticoid          hormone      1
# 1982  glucocorticoid         medicine      0
# 1984  glucocorticoid       base metal      0
# 1983  glucocorticoid     free radical      0
# 1981  glucocorticoid      environment      0
# 1985  glucocorticoid  high-fiber food      0
# ++++++++++++++
#
# Train Data -------------
# Empty DataFrame
# Columns: [concept, property]
# Index: []
# Test Data-----------
#                   concept                 property  label
# 454   cultural difference                   factor      1
# 1754  cultural difference               amino acid      0
# 1753  cultural difference  southeast asian country      0
# 1752  cultural difference             manufacturer      0
# 1751  cultural difference         natural resource      0
# 1755  cultural difference                  browser      0
# ++++++++++++++

# %%
train_test_overlap_df = pd.merge(train_df, test_pos_neg_data, how="inner", on = ["concept", "property"])

# %%
train_test_overlap_df
# Out:
# Empty DataFrame
# Columns: [concept, property, label]
# Index: []

# %%
test_train_overlap_df = pd.merge(test_pos_neg_data, train_df, how="inner", on = ["concept", "property"])

# %%
test_train_overlap_df
# Out:
# Empty DataFrame
# Columns: [concept, property, label]
# Index: []

# %%
train_valid_overlap_df = pd.merge(train_df, valid_df, how="inner", on = ["concept", "property"])

# %%
train_valid_overlap_df
# Out:
# Empty DataFrame
# Columns: [concept, property]
# Index: []

# %%
test_valid_overlap_df = pd.merge(test_df, valid_df, how="inner", on = ["concept", "property"])

# %%
test_valid_overlap_df
# Out:
# Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []

# %%
valid_df
# Out:
#                concept                       property
# 13             plastic                       material
# 18       key executive  detailed business information
# 22               metal                       material
# 30              stress                         factor
# 33              nausea                        symptom
# ...                ...                            ...
# 15022   czech republic       eastern european country
# 15023              can                      container
# 15012  carbon nanotube          carbon based material
# 15008          allergy                 health problem
# 15042         football              competitive sport
#
# [1465 rows x 2 columns]

# %%
test_df
# Out:
#          concept               property  num_relation
# 0    access code  supplemental material          8133
# 1           cost                 factor          5661
# 2      vegetable                   food          4638
# 3         nickel                  metal          4564
# 4           date            information          4463
# ..           ...                    ...           ...
# 676     lighting                 aspect           192
# 677  hydroxyzine          antihistamine           191
# 678      slipper         modern comfort           191
# 679       pollen              substance           191
# 680    vegetable        high-fiber food           191
#
# [681 rows x 3 columns]

# %%
# !pwd

# %%
train_df["concept"].unique()

# %%
np.sort(train_df["concept"].unique())

# %%
np.sort(test_df["concept"].unique())

# %%
train_df.dtypes

# %%
def generate_negative_data(data_df, num_neg_pair=1):
    
    data_df.reset_index(drop=True, inplace=True)
    
    #print ('data_df.index :',data_df.index)
        
    negative_data = []
    
    concept_list = data_df['concept'].unique()

    for concept in concept_list:
        
        negative_data_for_concept = []

        positive_data = data_df[data_df["concept"] == concept]
        #positive_data_index = data_df[data_df["concept"] == concept].index
        positive_data_index = np.array(positive_data.index)
        num_positive_data = len(positive_data_index)

        rest_df = data_df.drop(positive_data_index)
        rest_df.reset_index(drop=True, inplace=True)
        rest_df_idx = rest_df.index
        
        pos_or_negative = np.random.choice(['neg_concept', 'neg_property'], size=len(positive_data_index))
        
        num_neg_concept = Counter(pos_or_negative).get('neg_concept')
        num_neg_property = Counter(pos_or_negative).get('neg_property')
                
        print ('\n')
        print ('--' * 50 )
        print ('Concept :', concept)
        print ('len(positive_data):', len(positive_data))
        print ('num_neg_concept :',  num_neg_concept)
        print ('num_neg_property :', num_neg_property)
        print ('postitive_data_index :', positive_data_index)
        print ('\npositive_data:')
        print (positive_data)
        
        neg_concept_data = []
        neg_property_data = []
        
        
        # indexes of the records for which concept will be corrupted.
        if num_neg_concept is not None:
            
            neg_concept_record_idx = np.random.choice(positive_data_index, size=num_neg_concept)
            neg_concept = rest_df.sample(n = num_neg_pair * num_neg_concept)['concept'].to_numpy()
            neg_concept_split = np.split(neg_concept, len(neg_concept_record_idx))
            
            print ('\nneg_concepts')
            print (neg_concept)
            
            for array, idx in zip(neg_concept_split, neg_concept_record_idx):
                neg_concept_data.extend([(con, positive_data.loc[idx]['property'], 0) for con in array])                
        else:
            print ('num_neg_concept in None')
            neg_concept_record_idx = []
        
        print ('Negative concept for true property')
        print (neg_concept_data)

                
        if num_neg_property is not None:
            
            # indexes of the records for which property will be corrupted.
            #neg_property_record_idx = np.array([idx for idx in positive_data_index if idx not in neg_concept_record_idx])
            
            neg_property = rest_df.sample(n=num_neg_pair * num_neg_property)['property'].to_list()
            print ('\nneg_property :', neg_property)
            
            neg_property_data.extend([(concept, neg_prop, 0) for neg_prop in neg_property])
            
        print ('Negative Property data for true Concept :')
        print (neg_property_data)
            
        negative_data_for_concept.extend(neg_concept_data)
        negative_data_for_concept.extend(neg_property_data)
        
        print ('\nNumber of Negative Data For Concept :', len(negative_data_for_concept))
        print ('negative_data_for_concept:')
        print (negative_data_for_concept)
        
        negative_data.append(negative_data_for_concept)
        

    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)
    
    
    all_data = pd.concat([data_df, negative_data_df], ignore_index=True)
    
    all_data = all_data.sample(frac=1)
    all_data.drop_duplicates(inplace=True)
    
    print ('\nFinished Generating Data For One Set')
    print ('len(all_data) :', len(all_data))
    
    return all_data

# %%
print ('#' * 50)
print ('Generating Negative Train Data')

# %%
print ('\n Training Data')

# %%
pos_neg_train_df = generate_negative_data(train_df, num_neg_pair=num_neg_pair)
pos_neg_train_df.to_csv('data/65k_train_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Train Record Before Negative Data:', len(train_df))
print ('Train Record After Negative Data:', len(pos_neg_train_df))

# %%
print ('#' * 50)
print ('Generating Negative Valid Data')
print ('\n Validation Data')
pos_neg_val_df = generate_negative_data(valid_df, num_neg_pair=num_neg_pair)
pos_neg_val_df.to_csv('data/65k_valid_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Validation Record Before Negative Data:', len(valid_df))
print ('Validation Record After Negative Data:', len(pos_neg_val_df))

# %%
print ('#' * 50)
print ('Generating Negative Test Data')

print ('\n Test Data')
pos_neg_test_df = generate_negative_data(test_df, num_neg_pair=num_neg_pair)
pos_neg_test_df.to_csv('data/65k_test_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Test Record Before Negative Data:', len(test_df))
print ('Test Record After Negative Data:', len(pos_neg_test_df))
