# %%
import torch
import pandas as pd
import numpy as np

from collections import Counter

# %%
#file_path = "/scratch/c.scmag3/conceptEmbeddingModel/data/data-concept-instance-relations.txt" 
file_path = "./../../data/ms_concept_graph/data-concept-instance-relations.txt"
data_df = pd.read_csv(file_path, header=None, names=["property", "concept", "num_relation"], sep="\t")

# %%
print ('Data After Loading MS Concept Graph')
data_df
# Out:
# Data After Loading MS Concept Graph
#                                  property  \
# 0                                  factor
# 1                 free rich company datum
# 2                 free rich company datum
# 3                                   state
# 4                              supplement
# ...                                   ...
# 33377315   popular legacy datum structure
# 33377316                   norwegian food
# 33377317                     freeze skill
# 33377318  enhanced enforcement initiative
# 33377319  enhanced enforcement initiative
#
#                                              concept  num_relation
# 0                                                age         35167
# 1                                               size         33222
# 2                                            revenue         33185
# 3                                         california         18062
# 4                            msm glucosamine sulfate         15942
# ...                                              ...           ...
# 33377315                          binary search tree             1
# 33377316                                       lefse             1
# 33377317                                     new fot             1
# 33377318  monthly impact inspections of problem mine             1
# 33377319           pattern of violation notification             1
#
# [33377320 rows x 3 columns]

# %%
data_df.sort_values('num_relation', ascending=False, inplace=True)

# %%
print ('Data After Soring on Num Relation')
data_df
# Out:
# Data After Soring on Num Relation
#                                  property                            concept  \
# 0                                  factor                                age
# 1                 free rich company datum                               size
# 2                 free rich company datum                            revenue
# 3                                   state                         california
# 4                              supplement            msm glucosamine sulfate
# ...                                   ...                                ...
# 18841597        permanent control measure                       straw wattle
# 18841596        permanent control measure                          check dam
# 18841595        permanent control measure                  vegetative buffer
# 18841594        permanent control measure                       ditch lining
# 33377319  enhanced enforcement initiative  pattern of violation notification
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
data_df = data_df[['concept', 'property', 'num_relation']]
data_df
# Out:
#                                     concept                         property  \
# 0                                       age                           factor
# 1                                      size          free rich company datum
# 2                                   revenue          free rich company datum
# 3                                california                            state
# 4                   msm glucosamine sulfate                       supplement
# ...                                     ...                              ...
# 18841597                       straw wattle        permanent control measure
# 18841596                          check dam        permanent control measure
# 18841595                  vegetative buffer        permanent control measure
# 18841594                       ditch lining        permanent control measure
# 33377319  pattern of violation notification  enhanced enforcement initiative
#
#           num_relation
# 0                35167
# 1                33222
# 2                33185
# 3                18062
# 4                15942
# ...                ...
# 18841597             1
# 18841596             1
# 18841595             1
# 18841594             1
# 33377319             1
#
# [33377320 rows x 3 columns]

# %%
top_k = 15000

# %%
data_df = data_df[0:top_k]
print (f'Data Df after taking top {top_k} records \n:')
data_df
# Out:
# Data Df after taking top 15000 records
# :
#                        concept                   property  num_relation
# 0                          age                     factor         35167
# 1                         size    free rich company datum         33222
# 2                      revenue    free rich company datum         33185
# 3                   california                      state         18062
# 4      msm glucosamine sulfate                 supplement         15942
# ...                        ...                        ...           ...
# 15045                  dentist        health professional           191
# 15044              temperature    meteorological variable           191
# 15043                  toluene  volatile organic compound           191
# 15042                 football          competitive sport           191
# 15041                 medicaid        entitlement program           191
#
# [15000 rows x 3 columns]

# %%
unique_concept_list = data_df["concept"].unique()
# np.random.shuffle(unique_concept_list)
print (unique_concept_list.shape[0])
print (type(unique_concept_list))
# Out:
# 6006
# <class 'numpy.ndarray'>

# %%
num_unique_concepts = len(unique_concept_list)
print ('Num Unique Positive Concepts:', num_unique_concepts)
# Out:
# Num Unique Positive Concepts: 6006

# %%
print (data_df["concept"].value_counts())
# Out:
# age                             71
# water                           52
# temperature                     52
# diabetes                        45
# education                       44
#                                 ..
# generalized anxiety disorder     1
# exxonmobil                       1
# genetic background               1
# family income                    1
# tree removal                     1
# Name: concept, Length: 6006, dtype: int64

# %%
train_ratio, val_ratio, test_ratio = 0.85, 0.10, 0.05

# %%
num_train_concepts = int(num_unique_concepts * train_ratio)
num_val_concepts = int(num_unique_concepts * val_ratio)
num_test_concepts = int(num_unique_concepts * test_ratio)

print (num_train_concepts)
print (num_val_concepts)
print (num_test_concepts)
# Out:
# 5105
# 600
# 300

# %%
train_concept = unique_concept_list[0:num_train_concepts]
valid_concept = unique_concept_list[num_train_concepts:num_train_concepts + num_val_concepts]
test_concept = unique_concept_list[num_train_concepts + num_val_concepts:]

print ('Number of Positive Train Concept :', len(train_concept))
print ('Number of Positive Valid Concept :', len(valid_concept))
print ('Number of Positive Test Concept :', len(test_concept))
# Out:
# Number of Positive Train Concept : 5105
# Number of Positive Valid Concept : 600
# Number of Positive Test Concept : 301

# %% [markdown]
# print ('\nTrain Concept :', *train_concept, sep=", ")
# print ('\nValid Concept :', *valid_concept, sep=", ")
# print ('\nTest Concept :', *test_concept, sep=", ")

# %%
print ('Total Number of Positive Concepts :', num_train_concepts + num_val_concepts + num_test_concepts)
# Out:
# Total Number of Positive Concepts : 6005

# %%
print ('+' * 50)

print ('Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap')
assert set (train_concept) != set (valid_concept)
assert set (train_concept) != set (test_concept)
assert set (valid_concept) != set (test_concept)

print ('Assertions Passed')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Asserting Train Concept, Valid Concepts and Test Concpets Do Not Overlap
# Assertions Passed

# %%
train_df = data_df[data_df['concept'].isin(train_concept)]
valid_df = data_df[data_df['concept'].isin(valid_concept)]
test_df = data_df[data_df['concept'].isin(test_concept)]

print ('Number of Train Records :', len(train_df))
print ('Number of Valid Records :', len(valid_df))
print ('NUmber of Test Records :', len(test_df))

print ('+' * 50)
# Out:
# Number of Train Records : 14032
# Number of Valid Records : 661
# NUmber of Test Records : 307
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
print ('\ncheck if train, val and test dataframes have any overlap')
df = train_df.merge(test_df, how = 'inner' ,indicator=False)
print('\n', df)

df = train_df.merge(valid_df, how = 'inner' ,indicator=False)
print('\n', df)

df = test_df.merge(valid_df, how = 'inner', indicator=False)
print('\n', df)
# Out:
# check if train, val and test dataframes have any overlap
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []
#
#  Empty DataFrame
# Columns: [concept, property, num_relation]
# Index: []

# %%
train_df = train_df.drop("num_relation", axis=1)

# %%
train_df.to_csv("mscg_new_pos_train.tsv", sep="\t", index=None, header=None)

# %%
valid_df = valid_df.drop("num_relation", axis=1)

# %%
valid_df.to_csv("mscg_new_pos_valid.tsv", sep="\t", index=None, header=None)

# %%
def generate_pos_neg_test_data(test_df):
    
    # print (test_df.head())
    
    test_df.reset_index(drop=True, inplace=True)
    test_df = test_df.drop("num_relation", axis=1)
    test_df["label"] = 1
    
    test_df.set_index("concept", drop=False)
    
    print (test_df.head())
    print (test_df.shape)
    
    unique_test_concept = test_df["concept"].unique()
    
    print (len(unique_test_concept))
    
    negative_data = []
    for concept in unique_test_concept:
        
        temp_df = test_df[test_df["concept"] != concept]
        
        # print ("temp_df")
        # print (temp_df)
        
        sampled_property = np.random.choice(temp_df["property"].unique(), size=5, replace=False)
        
        # print ("sampled_property")
        # print (sampled_property)
        
        negative_data.append([(concept, prop, 0) for prop in sampled_property])
    
    
    # print ("negative_data")
    # print (len(negative_data))
    # print (negative_data)
    
    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)

    print("negative_data_df")
    print (negative_data_df.shape)
    
    all_data = pd.concat([test_df, negative_data_df], ignore_index=True)
    
    print("All Data")
    print (all_data.shape)
    
    all_data= all_data.sample(frac=1)
    
    all_data.to_csv("mscg_new_pos_neg_test.tsv", sep="\t", header=None, index=None)
    
    all_data.set_index("concept", drop=False)
    
    for concept in all_data["concept"].unique():
        print (all_data[all_data["concept"] == concept])
        print ()

    
generate_pos_neg_test_data(test_df)
# Out:
#        concept property  label
# 0     goldfish     fish      1
# 1        armor     item      1
# 2  forgiveness    topic      1
# 3        sound    topic      1
# 4   scheduling    issue      1
# (307, 3)
# 301
# negative_data_df
# (1505, 3)
# All Data
# (1812, 3)
#             concept          property  label
# 1000  janet jackson  operating system      0
# 999   janet jackson           setting      0
# 1001  janet jackson    modern comfort      0
# 997   janet jackson    funding source      0
# 138   janet jackson  a-list celebrity      1
# 998   janet jackson         pollutant      0
#
#      concept       property  label
# 181    tesla        company      1
# 1215   tesla       language      0
# 1214   tesla     body fluid      0
# 1216   tesla       software      0
# 1213   tesla        feature      0
# 1212   tesla  neutral color      0
#
#       concept      property  label
# 1044  luggage      exercise      0
# 1042  luggage          cost      0
# 1043  luggage      compound      0
# 1046  luggage  distribution      0
# 147   luggage          item      1
# 1045  luggage        object      0
#
#                  concept        property  label
# 1714  demographic change  funding source      0
# 1713  demographic change     alkyl group      0
# 1715  demographic change          effect      0
# 285   demographic change          factor      1
# 1712  demographic change    tree service      0
# 1716  demographic change           sport      0
#
#        concept                  property  label
# 655  sao paulo  eastern european country      0
# 652  sao paulo                      task      0
# 69   sao paulo                      city      1
# 656  sao paulo      limited circumstance      0
# 654  sao paulo                    factor      0
# 653  sao paulo            market dynamic      0
#
#     concept       property  label
# 514    aloe     ingredient      0
# 41     aloe     ingredient      1
# 513    aloe    credit card      0
# 516    aloe  hash function      0
# 515    aloe        allergy      0
# 512    aloe         device      0
#
#      concept    property  label
# 1294  scopus  medication      0
# 1292  scopus       breed      0
# 1295  scopus       issue      0
# 1296  scopus    material      0
# 197   scopus    database      1
# 1293  scopus        area      0
#
#      concept              property  label
# 44   comfrey                  herb      1
# 529  comfrey               feature      0
# 528  comfrey   heavy cleaning duty      0
# 531  comfrey  limited circumstance      0
# 527  comfrey             character      0
# 530  comfrey               allergy      0
#
#              concept            property  label
# 1129  telephone call  musicianship skill      0
# 1127  telephone call                item      0
# 1131  telephone call           character      0
# 164   telephone call    personal expense      1
# 1128  telephone call           equipment      0
# 1130  telephone call        distribution      0
#
#                   concept           property  label
# 1719  personal preference            keyword      0
# 1720  personal preference            company      0
# 1718  personal preference          accessory      0
# 1721  personal preference    african country      0
# 1717  personal preference  magnetic property      0
# 287   personal preference             factor      1
#
#          concept       property  label
# 743  study skill  antihistamine      0
# 744  study skill        protein      0
# 746  study skill      cell line      0
# 742  study skill          nsaid      0
# 745  study skill        allergy      0
# 87   study skill          topic      1
#
#         concept                       property  label
# 1290  mast cell                    preparation      0
# 1287  mast cell                          sugar      0
# 1288  mast cell  personal protective equipment      0
# 1291  mast cell          aliphatic hydrocarbon      0
# 1289  mast cell              regulatory agency      0
# 196   mast cell                           cell      1
#
#        concept       property  label
# 648  sweetener       language      0
# 651  sweetener  plant hormone      0
# 649  sweetener          title      0
# 647  sweetener           task      0
# 650  sweetener           cell      0
# 68   sweetener     ingredient      1
#
#     concept      property  label
# 915   adida    medication      0
# 912   adida     situation      0
# 914   adida          fish      0
# 916   adida  lean protein      0
# 913   adida  tree service      0
# 121   adida         brand      1
#
#             concept                   property  label
# 1178  chemical peel                   software      0
# 1179  chemical peel                alkyl group      0
# 1180  chemical peel  smokeless tobacco product      0
# 1177  chemical peel                information      0
# 1181  chemical peel                  character      0
# 174   chemical peel                  treatment      1
#
#      concept                 property  label
# 42   podcast               technology      1
# 517  podcast                cell line      0
# 521  podcast          chelating agent      0
# 518  podcast  manipulating identifier      0
# 519  podcast         optical property      0
# 520  podcast                     fish      0
#
#       concept        property  label
# 1370  sunroof  disturbed area      0
# 1368  sunroof       cell line      0
# 1369  sunroof    light source      0
# 212   sunroof         feature      1
# 1367  sunroof        language      0
# 1371  sunroof     information      0
#
#     concept      property  label
# 7      high        factor      1
# 345    high     bacterium      0
# 342    high     character      0
# 344    high          city      0
# 346    high     stimulant      0
# 343    high  neuropeptide      0
#
#      concept              property  label
# 906  soil ph  electrical appliance      0
# 902  soil ph           application      0
# 119  soil ph                factor      1
# 904  soil ph         neutral color      0
# 905  soil ph         close contact      0
# 903  soil ph                artist      0
#
#              concept                      property  label
# 1150  chicken breast                      database      0
# 1148  chicken breast  low molecular weight heparin      0
# 1149  chicken breast              operating system      0
# 168   chicken breast                  lean protein      1
# 1151  chicken breast                      resource      0
# 1147  chicken breast                     treatment      0
#
#               concept          property  label
# 225   endophthalmitis      complication      1
# 1432  endophthalmitis           emotion      0
# 1436  endophthalmitis         cell line      0
# 1433  endophthalmitis         organelle      0
# 1435  endophthalmitis         vegetable      0
# 1434  endophthalmitis  personal expense      0
#
#                              concept             property  label
# 1267  contract research organization      chelating agent      0
# 192   contract research organization          third party      1
# 1269  contract research organization    patient care unit      0
# 1270  contract research organization           lewis acid      0
# 1268  contract research organization            condition      0
# 1271  contract research organization  heavy cleaning duty      0
#
#         concept                           property  label
# 123  neil young                             artist      1
# 922  neil young                               fish      0
# 924  neil young                            service      0
# 925  neil young  serious gastrointestinal toxicity      0
# 926  neil young                             factor      0
# 923  neil young                           cytokine      0
#
#      concept                           property  label
# 1399    taxi  serious gastrointestinal toxicity      0
# 1398    taxi                       neuropeptide      0
# 1400    taxi                       central bank      0
# 218     taxi                            vehicle      1
# 1401    taxi                             object      0
# 1397    taxi                            company      0
#
#     concept        property  label
# 539     cbs       perennial      0
# 46      cbs         network      1
# 538     cbs    complication      0
# 541     cbs  market dynamic      0
# 537     cbs    coated metal      0
# 540     cbs   close contact      0
#
#     concept               property  label
# 505     aim                   game      0
# 503     aim                 effect      0
# 504     aim                mineral      0
# 506     aim  aliphatic hydrocarbon      0
# 39      aim                   word      1
# 502     aim                  issue      0
#
#               concept             property  label
# 166   polyisobutylene  synthetic elastomer      1
# 1139  polyisobutylene         complication      0
# 1140  polyisobutylene          preparation      0
# 1141  polyisobutylene         tree service      0
# 1137  polyisobutylene                 part      0
# 1138  polyisobutylene            pollutant      0
#
#      concept         property  label
# 621  scraper          keyword      0
# 619  scraper  natural process      0
# 62   scraper             tool      1
# 618  scraper            state      0
# 620  scraper       lewis acid      0
# 617  scraper       regulation      0
#
#          concept                   property  label
# 392  hydrocarbon                       city      0
# 396  hydrocarbon            eating disorder      0
# 393  hydrocarbon  dispute resolution method      0
# 17   hydrocarbon                  pollutant      1
# 395  hydrocarbon               neuropeptide      0
# 394  hydrocarbon                   additive      0
#
#                 concept            property  label
# 1782  client s creditor                city      0
# 300   client s creditor         third party      1
# 1784  client s creditor  alpha hydroxy acid      0
# 1785  client s creditor                item      0
# 1783  client s creditor        central bank      0
# 1786  client s creditor               nsaid      0
#
#      concept                property  label
# 1722   czech                 feature      0
# 1723   czech                    food      0
# 1725   czech  transcription enhancer      0
# 288    czech                language      1
# 1726   czech                    cell      0
# 1724   czech                 journal      0
#
#           concept                  property  label
# 1573  pulse width  eastern european country      0
# 255   pulse width                 parameter      1
# 1574  pulse width               soy product      0
# 1576  pulse width                 accessory      0
# 1575  pulse width                medication      0
# 1572  pulse width                   product      0
#
#      concept         property  label
# 217    quake             game      1
# 1393   quake     complication      0
# 1395   quake         material      0
# 1392   quake         database      0
# 1394   quake    hash function      0
# 1396   quake  chelating agent      0
#
#      concept          property  label
# 32   harness         equipment      1
# 467  harness  optical property      0
# 471  harness     medium player      0
# 468  harness              item      0
# 469  harness          cytokine      0
# 470  harness    disturbed area      0
#
#       concept        property  label
# 1033  highway  disturbed area      0
# 1032  highway        festival      0
# 1034  highway      technology      0
# 145   highway         surface      1
# 1036  highway       appliance      0
# 1035  highway         vitamin      0
#
#      concept         property  label
# 741  fencing      soy product      0
# 737  fencing  eating disorder      0
# 739  fencing    essential oil      0
# 738  fencing            title      0
# 86   fencing            sport      1
# 740  fencing             food      0
#
#     concept               property  label
# 412  rwanda  aliphatic hydrocarbon      0
# 415  rwanda       optical property      0
# 413  rwanda            insecticide      0
# 21   rwanda        african country      1
# 414  rwanda           coated metal      0
# 416  rwanda                   role      0
#
#                concept            property  label
# 1050  sports equipment        health issue      0
# 1048  sports equipment             symptom      0
# 1051  sports equipment            document      0
# 1049  sports equipment   magnetic property      0
# 1047  sports equipment  infectious disease      0
# 148   sports equipment                item      1
#
#          concept        property  label
# 175   web server     application      1
# 1183  web server     soy product      0
# 1182  web server       character      0
# 1184  web server          entity      0
# 1185  web server    tree service      0
# 1186  web server  disturbed area      0
#
#         concept       property  label
# 483  thermostat          topic      0
# 482  thermostat  blood thinner      0
# 35   thermostat         device      1
# 485  thermostat       province      0
# 486  thermostat  close contact      0
# 484  thermostat         injury      0
#
#     concept             property  label
# 463   moses           regulation      0
# 462   moses  heavy cleaning duty      0
# 465   moses            equipment      0
# 466   moses                 meat      0
# 31    moses              prophet      1
# 464   moses               defect      0
#
#     concept    property  label
# 497  spacer  pyrethroid      0
# 38   spacer     product      1
# 500  spacer   perennial      0
# 498  spacer     amenity      0
# 499  spacer      entity      0
# 501  spacer  regulation      0
#
#         concept                    property  label
# 1194  autofocus  polyunsaturated fatty acid      0
# 1195  autofocus                       state      0
# 1192  autofocus                     protein      0
# 1193  autofocus                     mineral      0
# 1196  autofocus                     vitamin      0
# 177   autofocus                     feature      1
#
#      concept              property  label
# 1442    envy  limited circumstance      0
# 1444    envy               company      0
# 1446    envy               service      0
# 227     envy               emotion      1
# 1443    envy                  meat      0
# 1445    envy      plasma parameter      0
#
#          concept             property  label
# 117  real object                 tool      1
# 893  real object     serial interface      0
# 895  real object               factor      0
# 894  real object  heavy cleaning duty      0
# 896  real object        blood thinner      0
# 892  real object     natural disaster      0
#
#        concept          property  label
# 163   positive           pattern      1
# 1126  positive           solvent      0
# 1122  positive     blood thinner      0
# 1123  positive  plasma parameter      0
# 1124  positive           amenity      0
# 1125  positive           vehicle      0
#
#              concept             property  label
# 167   sodium sulfite  antioxidizing agent      1
# 1146  sodium sulfite                 item      0
# 1145  sodium sulfite       market dynamic      0
# 1144  sodium sulfite             property      0
# 1143  sodium sulfite             document      0
# 1142  sodium sulfite        antihistamine      0
#
#         concept           property  label
# 1611  aggregate           particle      0
# 1608  aggregate         pyrethroid      0
# 1609  aggregate  patient care unit      0
# 1610  aggregate               meat      0
# 1607  aggregate               fish      0
# 263   aggregate           material      1
#
#      concept          property  label
# 1634      b2  operating system      0
# 1635      b2         perennial      0
# 268       b2           vitamin      1
# 1636      b2            animal      0
# 1632      b2     essential oil      0
# 1633      b2         condition      0
#
#                          concept         property  label
# 1691  search engine optimization         province      0
# 1687  search engine optimization             cell      0
# 1690  search engine optimization            title      0
# 1688  search engine optimization           device      0
# 280   search engine optimization          service      1
# 1689  search engine optimization  chelating agent      0
#
#                   concept                  property  label
# 92   chemical composition                    factor      1
# 767  chemical composition                 character      0
# 768  chemical composition  eastern european country      0
# 769  chemical composition                     issue      0
# 771  chemical composition                  particle      0
# 770  chemical composition                    sensor      0
#
#              concept             property  label
# 1538  healthy eating                sugar      0
# 1540  healthy eating             industry      0
# 1539  healthy eating             software      0
# 1537  healthy eating  heavy cleaning duty      0
# 248   healthy eating                topic      1
# 1541  healthy eating                title      0
#
#          concept          property  label
# 141   galvanized      coated metal      1
# 1013  galvanized  serial interface      0
# 1016  galvanized    market dynamic      0
# 1015  galvanized           amenity      0
# 1012  galvanized           vitamin      0
# 1014  galvanized       cruise line      0
#
#      concept        property  label
# 1694    lisp            part      0
# 1696    lisp  funding source      0
# 1692    lisp        material      0
# 1695    lisp         company      0
# 281     lisp        language      1
# 1693    lisp            tool      0
#
#      concept          property  label
# 1307     hcv              meat      0
# 1309     hcv    modern comfort      0
# 1311     hcv         treatment      0
# 1308     hcv  optical property      0
# 200      hcv             virus      1
# 1310     hcv    market dynamic      0
#
#      concept                    property  label
# 1248    nato                       organ      0
# 1247    nato                   equipment      0
# 188     nato  international organization      1
# 1250    nato                     product      0
# 1249    nato                       asset      0
# 1251    nato              sleep disorder      0
#
#     concept            property  label
# 585   a1000    operating system      0
# 586   a1000            document      0
# 583   a1000           vegetable      0
# 584   a1000            facility      0
# 55    a1000       omron product      1
# 582   a1000  musicianship skill      0
#
#                 concept            property  label
# 489  stem cell research         third party      0
# 488  stem cell research        coated metal      0
# 491  stem cell research         cruise line      0
# 490  stem cell research  infectious disease      0
# 36   stem cell research               issue      1
# 487  stem cell research            particle      0
#
#                   concept      property  label
# 455  blood pressure check       journal      0
# 454  blood pressure check  lean protein      0
# 452  blood pressure check         breed      0
# 453  blood pressure check     stimulant      0
# 456  blood pressure check       mineral      0
# 29   blood pressure check  health issue      1
#
#            concept      property  label
# 1811  tree removal      resource      0
# 1808  tree removal         organ      0
# 1810  tree removal    lewis acid      0
# 1809  tree removal      facility      0
# 305   tree removal  tree service      1
# 1807  tree removal        artist      0
#
#           concept                      property  label
# 716  email header  low molecular weight heparin      0
# 81   email header       manipulating identifier      1
# 712  email header                       network      0
# 713  email header                          cost      0
# 714  email header                         genre      0
# 715  email header                 vegetable oil      0
#
#     concept          property  label
# 963   drone          property      0
# 131   drone        technology      1
# 966   drone              cost      0
# 962   drone             video      0
# 964   drone  natural disaster      0
# 965   drone         bacterium      0
#
#          concept              property  label
# 368  google maps  electrical appliance      0
# 371  google maps            lewis acid      0
# 369  google maps                  band      0
# 12   google maps           application      1
# 367  google maps              facility      0
# 370  google maps               product      0
#
#     concept                   property  label
# 668   plank                      video      0
# 72    plank                   exercise      1
# 669   plank                    mineral      0
# 670   plank             disturbed area      0
# 667   plank              neutral color      0
# 671   plank  dispute resolution method      0
#
#        concept                property  label
# 872  neck pain              lewis acid      0
# 874  neck pain              pyrethroid      0
# 876  neck pain           vegetable oil      0
# 113  neck pain                 symptom      1
# 873  neck pain          funding source      0
# 875  neck pain  transcription enhancer      0
#
#       concept               property  label
# 848  soy milk                emotion      0
# 847  soy milk                   part      0
# 851  soy milk  aliphatic hydrocarbon      0
# 849  soy milk               property      0
# 850  soy milk                  sport      0
# 108  soy milk            soy product      1
#
#     concept                    property  label
# 689   spoon  polyunsaturated fatty acid      0
# 687   spoon                        part      0
# 76    spoon                      object      1
# 688   spoon                   bacterium      0
# 690   spoon                        role      0
# 691   spoon                    compound      0
#
#      concept          property  label
# 1463  levi s          specimen      0
# 231   levi s             brand      1
# 1462  levi s  natural disaster      0
# 1464  levi s       third party      0
# 1465  levi s       soy product      0
# 1466  levi s           surface      0
#
#             concept           property  label
# 1448  diesel engine      medium player      0
# 228   diesel engine  combustion engine      1
# 1450  diesel engine        preparation      0
# 1449  diesel engine             defect      0
# 1447  diesel engine               band      0
# 1451  diesel engine              sport      0
#
#      concept     property  label
# 990  autocad     additive      0
# 987  autocad      journal      0
# 136  autocad     software      1
# 988  autocad      setting      0
# 989  autocad   body fluid      0
# 991  autocad  soy product      0
#
#      concept            property  label
# 1616     tan         insecticide      0
# 1614     tan  musicianship skill      0
# 1612     tan            database      0
# 1615     tan        light source      0
# 1613     tan            province      0
# 264      tan       neutral color      1
#
#     concept       property  label
# 103   broth         liquid      1
# 823   broth      accessory      0
# 826   broth  antihistamine      0
# 825   broth           city      0
# 824   broth     pyrethroid      0
# 822   broth        keyword      0
#
#        concept          property  label
# 613  professor  a-list celebrity      0
# 616  professor           surface      0
# 61   professor             title      1
# 612  professor       soy product      0
# 614  professor     neutral color      0
# 615  professor      neuropeptide      0
#
#      concept                       property  label
# 717  kissing               operating system      0
# 719  kissing  personal protective equipment      0
# 721  kissing                       particle      0
# 718  kissing                       organism      0
# 82   kissing                  close contact      1
# 720  kissing                       specimen      0
#
#      concept                  property  label
# 957  haddock                  database      0
# 130  haddock                      fish      1
# 958  haddock                     skill      0
# 960  haddock  eastern european country      0
# 961  haddock                    liquid      0
# 959  haddock                      fish      0
#
#          concept                 property  label
# 321  forgiveness  manipulating identifier      0
# 320  forgiveness            mobile device      0
# 2    forgiveness                    topic      1
# 318  forgiveness                  emotion      0
# 319  forgiveness    aliphatic hydrocarbon      0
# 317  forgiveness                perennial      0
#
#      concept           property  label
# 1332     md5    african country      0
# 1336     md5        soy product      0
# 1333     md5              drink      0
# 1334     md5               area      0
# 205      md5      hash function      1
# 1335     md5  regulatory agency      0
#
#                              concept            property  label
# 432  ethylenediaminetetraacetic acid  autoimmune disease      0
# 25   ethylenediaminetetraacetic acid     chelating agent      1
# 433  ethylenediaminetetraacetic acid           stimulant      0
# 434  ethylenediaminetetraacetic acid                film      0
# 435  ethylenediaminetetraacetic acid                cost      0
# 436  ethylenediaminetetraacetic acid     african country      0
#
#             concept        property  label
# 1073  white balance  sleep disorder      0
# 1075  white balance    tree service      0
# 1076  white balance     preparation      0
# 1074  white balance         service      0
# 153   white balance         setting      1
# 1072  white balance      regulation      0
#
#                 concept                       property  label
# 548  hearing protection                        journal      0
# 551  hearing protection                      equipment      0
# 547  hearing protection              patient care unit      0
# 48   hearing protection  personal protective equipment      1
# 549  hearing protection        manipulating identifier      0
# 550  hearing protection         transcription enhancer      0
#
#                   concept           property  label
# 27   cadmium plated steel       coated metal      1
# 445  cadmium plated steel  combustion engine      0
# 443  cadmium plated steel            solvent      0
# 446  cadmium plated steel       health issue      0
# 442  cadmium plated steel            journal      0
# 444  cadmium plated steel         ingredient      0
#
#                  concept       property  label
# 425  chemical resistance          sport      0
# 424  chemical resistance      parameter      0
# 426  chemical resistance        journal      0
# 23   chemical resistance       property      1
# 422  chemical resistance           food      0
# 423  chemical resistance  hash function      0
#
#         concept                  property  label
# 53   laceration                    injury      1
# 574  laceration                pyrethroid      0
# 576  laceration  eastern european country      0
# 573  laceration             neutral color      0
# 572  laceration                 organelle      0
# 575  laceration                     virus      0
#
#         concept           property  label
# 330  scheduling  regulatory agency      0
# 327  scheduling      essential oil      0
# 329  scheduling            prophet      0
# 4    scheduling              issue      1
# 279  scheduling               task      1
# 328  scheduling            service      0
# 331  scheduling            symptom      0
#
#      concept                       property  label
# 1069    hair                           area      0
# 1071    hair                          state      0
# 1070    hair                       province      0
# 152     hair                       material      1
# 1068    hair  personal protective equipment      0
# 1067    hair                  system device      0
#
#        concept    property  label
# 1589  adelaide       skill      0
# 1588  adelaide      method      0
# 1591  adelaide  identifier      0
# 1587  adelaide     setting      0
# 1590  adelaide       virus      0
# 258   adelaide        city      1
#
#           concept      property  label
# 1314  dispersants      resource      0
# 1316  dispersants   preparation      0
# 1315  dispersants  distribution      0
# 1312  dispersants     situation      0
# 1313  dispersants          food      0
# 201   dispersants      additive      1
#
#            concept            property  label
# 1246  magnetometer        central bank      0
# 1245  magnetometer  infectious disease      0
# 1244  magnetometer                food      0
# 1243  magnetometer       mobile device      0
# 187   magnetometer              sensor      1
# 1242  magnetometer                bird      0
#
#             concept                      property  label
# 1503  zinc chloride  addiction treatment approach      0
# 1506  zinc chloride                    technology      0
# 239   zinc chloride                    lewis acid      1
# 1505  zinc chloride                     incentive      0
# 1504  zinc chloride                       product      0
# 1502  zinc chloride                        effect      0
#
#     concept          property  label
# 950   suede  natural disaster      0
# 949   suede     antihistamine      0
# 951   suede         vegetable      0
# 948   suede            object      0
# 947   suede          resource      0
# 128   suede          material      1
#
#        concept       property  label
# 101  developer           role      1
# 814  developer     identifier      0
# 815  developer  system device      0
# 816  developer       property      0
# 812  developer           food      0
# 813  developer      pollutant      0
#
#             concept             property  label
# 112  black or white                video      1
# 871  black or white              product      0
# 870  black or white              firearm      0
# 868  black or white        mobile device      0
# 867  black or white               method      0
# 869  black or white  antioxidizing agent      0
#
#          concept          property  label
# 1102  amiodarone    disturbed area      0
# 1104  amiodarone      coated metal      0
# 159   amiodarone        medication      1
# 1106  amiodarone            method      0
# 1103  amiodarone          specimen      0
# 1105  amiodarone  suitable utensil      0
#
#      concept       property  label
# 1514  plavix        company      0
# 1513  plavix    soy product      0
# 242   plavix  blood thinner      1
# 1515  plavix     medication      0
# 1512  plavix           game      0
# 1516  plavix       property      0
#
#     concept            property  label
# 28    rifle             firearm      1
# 449   rifle      disturbed area      0
# 450   rifle               video      0
# 451   rifle          ingredient      0
# 448   rifle    operating system      0
# 447   rifle  alpha hydroxy acid      0
#
#      concept       property  label
# 1286  sputum       material      0
# 1282  sputum      appliance      0
# 1283  sputum  omron product      0
# 1285  sputum          virus      0
# 195   sputum       specimen      1
# 1284  sputum       industry      0
#
#         concept            property  label
# 1324  dictation      market dynamic      0
# 1326  dictation       system device      0
# 1323  dictation             keyword      0
# 1325  dictation            activity      0
# 203   dictation  musicianship skill      1
# 1322  dictation            facility      0
#
#      concept            property  label
# 1623    sars           incentive      0
# 266     sars  infectious disease      1
# 1626    sars               title      0
# 1622    sars               virus      0
# 1624    sars   regulatory agency      0
# 1625    sars         soy product      0
#
#        concept         property  label
# 1163  nematode         document      0
# 1164  nematode       pyrethroid      0
# 171   nematode         organism      1
# 1165  nematode     neuropeptide      0
# 1162  nematode         activity      0
# 1166  nematode  african country      0
#
#      concept    property  label
# 1175  garden       virus      0
# 1176  garden    beverage      0
# 1174  garden        role      0
# 1172  garden  regulation      0
# 1173  garden        part      0
# 173   garden        area      1
#
#                             concept           property  label
# 829  nonsteroidal anti inflammatory        soy product      0
# 827  nonsteroidal anti inflammatory  magnetic property      0
# 831  nonsteroidal anti inflammatory             method      0
# 104  nonsteroidal anti inflammatory         medication      1
# 830  nonsteroidal anti inflammatory        insecticide      0
# 828  nonsteroidal anti inflammatory               tool      0
#
#      concept         property  label
# 1501  driver             part      0
# 1498  driver          allergy      0
# 1497  driver      cruise line      0
# 238   driver   market dynamic      1
# 1499  driver  chelating agent      0
# 1500  driver     distribution      0
#
#        concept          property  label
# 178   ideology            factor      1
# 1198  ideology           allergy      0
# 1199  ideology  operating system      0
# 1200  ideology             topic      0
# 1201  ideology          language      0
# 1197  ideology        ingredient      0
#
#     concept                           property  label
# 994   hexyl                    eating disorder      0
# 996   hexyl  serious gastrointestinal toxicity      0
# 995   hexyl                         regulation      0
# 993   hexyl                      plant hormone      0
# 992   hexyl                     market dynamic      0
# 137   hexyl                        alkyl group      1
#
#     concept          property  label
# 534    note      alkali metal      0
# 535    note  operating system      0
# 536    note        ingredient      0
# 45     note       information      1
# 532    note     mobile device      0
# 533    note    disturbed area      0
#
#      concept        property  label
# 1740   chalk   omron product      0
# 1738   chalk        particle      0
# 291    chalk        material      1
# 1737   chalk       stimulant      0
# 1741   chalk  bronchodilator      0
# 1739   chalk    health issue      0
#
#          concept                   property  label
# 643  tachycardia           serial interface      0
# 67   tachycardia                    symptom      1
# 645  tachycardia                    vehicle      0
# 642  tachycardia  dispute resolution method      0
# 646  tachycardia                     liquid      0
# 644  tachycardia       limited circumstance      0
#
#                 concept     property  label
# 581  wedding invitation    substrate      0
# 577  wedding invitation  information      0
# 579  wedding invitation       artist      0
# 580  wedding invitation    equipment      0
# 54   wedding invitation      purpose      1
# 578  wedding invitation        genre      0
#
#        concept          property  label
# 1496  ethernet          additive      0
# 1493  ethernet            injury      0
# 1495  ethernet     hash function      0
# 237   ethernet  serial interface      1
# 1494  ethernet           service      0
# 1492  ethernet             genre      0
#
#       concept       property  label
# 1256  user id  hash function      0
# 1253  user id         injury      0
# 189   user id    information      1
# 1252  user id      situation      0
# 1255  user id  mobile device      0
# 1254  user id      appliance      0
#
#        concept             property  label
# 1415  hamilton                genre      0
# 1413  hamilton   infectious disease      0
# 1412  hamilton               device      0
# 1414  hamilton      natural process      0
# 1416  hamilton  antioxidizing agent      0
# 221   hamilton                 city      1
#
#       concept  property  label
# 63   manpower  resource      1
# 624  manpower  particle      0
# 626  manpower  document      0
# 625  manpower  composer      0
# 623  manpower      herb      0
# 622  manpower     sugar      0
#
#      concept          property  label
# 930  railway       third party      0
# 929  railway            method      0
# 124  railway          industry      1
# 931  railway  serial interface      0
# 927  railway             nsaid      0
# 928  railway          document      0
#
#     concept            property  label
# 570  roller         alkyl group      0
# 571  roller  infectious disease      0
# 52   roller                part      1
# 567  roller           perennial      0
# 568  roller             company      0
# 569  roller              object      0
#
#     concept       property  label
# 880   aetna   neuropeptide      0
# 877   aetna      stimulant      0
# 881   aetna          organ      0
# 878   aetna   lean protein      0
# 879   aetna  essential oil      0
# 114   aetna        company      1
#
#                concept         property  label
# 1683  loose connection  natural process      0
# 1685  loose connection            genre      0
# 278   loose connection           defect      1
# 1686  loose connection          vehicle      0
# 1682  loose connection         cytokine      0
# 1684  loose connection        substrate      0
#
#        concept                    property  label
# 1037  postcard      transcription enhancer      0
# 1038  postcard                    organism      0
# 1040  postcard                     solvent      0
# 1039  postcard  polyunsaturated fatty acid      0
# 1041  postcard                       sugar      0
# 146   postcard                        item      1
#
#     concept                    property  label
# 390  reggae               plant hormone      0
# 389  reggae                   stimulant      0
# 391  reggae                        band      0
# 388  reggae  polyunsaturated fatty acid      0
# 16   reggae                       genre      1
# 387  reggae                        cell      0
#
#                      concept     property  label
# 759  adaptive cruise control       injury      0
# 761  adaptive cruise control     resource      0
# 90   adaptive cruise control      feature      1
# 758  adaptive cruise control    situation      0
# 760  adaptive cruise control  third party      0
# 757  adaptive cruise control        state      0
#
#                 concept              property  label
# 775  hormonal imbalance            technology      0
# 93   hormonal imbalance                factor      1
# 772  hormonal imbalance                object      0
# 774  hormonal imbalance                  film      0
# 773  hormonal imbalance  limited circumstance      0
# 776  hormonal imbalance        bronchodilator      0
#
#              concept                      property  label
# 704  drug counseling                     organelle      0
# 79   drug counseling  addiction treatment approach      1
# 706  drug counseling                  lean protein      0
# 705  drug counseling                   insecticide      0
# 703  drug counseling                        method      0
# 702  drug counseling                       feature      0
#
#            concept             property  label
# 977  glycolic acid       disturbed area      0
# 978  glycolic acid     natural disaster      0
# 134  glycolic acid   alpha hydroxy acid      1
# 980  glycolic acid                 role      0
# 981  glycolic acid  heavy cleaning duty      0
# 979  glycolic acid          insecticide      0
#
#         concept                 property  label
# 1519  beethoven                  protein      0
# 1521  beethoven                 property      0
# 1517  beethoven                  pattern      0
# 1518  beethoven  manipulating identifier      0
# 243   beethoven                 composer      1
# 1520  beethoven               technology      0
#
#      concept                      property  label
# 1407   hippo                        sensor      0
# 1410   hippo                   cruise line      0
# 1408   hippo               chelating agent      0
# 1411   hippo          limited circumstance      0
# 220    hippo                        animal      1
# 1409   hippo  low molecular weight heparin      0
#
#      concept       property  label
# 1789   liver    application      0
# 301    liver          organ      1
# 1787   liver     medication      0
# 1788   liver  hash function      0
# 1790   liver          brand      0
# 1791   liver           cost      0
#
#               concept                       property  label
# 890  waste management  personal protective equipment      0
# 891  waste management                     lewis acid      0
# 888  waste management                      incentive      0
# 116  waste management                          issue      1
# 889  waste management                           bird      0
# 887  waste management                   tree service      0
#
#         concept               property  label
# 1552  potential       personal expense      0
# 1554  potential  aliphatic hydrocarbon      0
# 1553  potential                   meat      0
# 1556  potential                   area      0
# 251   potential                   word      1
# 1555  potential          antihistamine      0
#
#                concept             property  label
# 1665  wireless network               effect      0
# 1664  wireless network              protein      0
# 1662  wireless network  antioxidizing agent      0
# 1666  wireless network        neutral color      0
# 1663  wireless network        system device      0
# 274   wireless network     serial interface      1
#
#       concept               property  label
# 1055  heptane         modern comfort      0
# 1056  heptane                prophet      0
# 149   heptane                solvent      1
# 240   heptane  aliphatic hydrocarbon      1
# 1052  heptane             body fluid      0
# 1053  heptane              cell line      0
# 1054  heptane                 liquid      0
#
#          concept                   property  label
# 1478  evaluation              plant hormone      0
# 1479  evaluation  smokeless tobacco product      0
# 234   evaluation                      skill      1
# 1480  evaluation      aliphatic hydrocarbon      0
# 1481  evaluation                  character      0
# 1477  evaluation         alpha hydroxy acid      0
#
#         concept            property  label
# 1066  classroom  alpha hydroxy acid      0
# 1064  classroom           situation      0
# 1065  classroom            additive      0
# 1062  classroom             amenity      0
# 1063  classroom           incentive      0
# 151   classroom            facility      1
#
#         concept                      property  label
# 1650  magnetite                 omron product      0
# 1647  magnetite                    body fluid      0
# 1649  magnetite                    identifier      0
# 1648  magnetite  low molecular weight heparin      0
# 271   magnetite                       mineral      1
# 1651  magnetite                          item      0
#
#           concept              property  label
# 1532  cryotherapy             vegetable      0
# 246   cryotherapy             treatment      1
# 1533  cryotherapy          tree service      0
# 1536  cryotherapy          coated metal      0
# 1534  cryotherapy  limited circumstance      0
# 1535  cryotherapy         close contact      0
#
#        concept       property  label
# 607  hay fever      cell line      0
# 611  hay fever           band      0
# 60   hay fever        allergy      1
# 610  hay fever  mobile device      0
# 609  hay fever           tool      0
# 608  hay fever       province      0
#
#         concept   property  label
# 803  sound card  incentive      0
# 802  sound card      skill      0
# 806  sound card    vehicle      0
# 805  sound card    service      0
# 99   sound card     device      1
# 804  sound card   particle      0
#
#       concept      property  label
# 1644  bologna      industry      0
# 1643  bologna       company      0
# 1642  bologna         issue      0
# 1646  bologna        artist      0
# 270   bologna          meat      1
# 1645  bologna  coated metal      0
#
#        concept          property  label
# 34   key chain              item      1
# 479  key chain        amino acid      0
# 478  key chain  natural disaster      0
# 480  key chain              food      0
# 481  key chain         stimulant      0
# 477  key chain              city      0
#
#           concept            property  label
# 179   social norm              factor      1
# 1204  social norm               skill      0
# 1202  social norm  musicianship skill      0
# 1206  social norm             amenity      0
# 1205  social norm        central bank      0
# 1203  social norm       system device      0
#
#                 concept                      property  label
# 1278  dextroamphetamine                  health issue      0
# 194   dextroamphetamine                     stimulant      1
# 1281  dextroamphetamine                      beverage      0
# 1280  dextroamphetamine              natural disaster      0
# 1277  dextroamphetamine                   alkyl group      0
# 1279  dextroamphetamine  addiction treatment approach      0
#
#       concept            property  label
# 1021  fasting               organ      0
# 1018  fasting       mobile device      0
# 142   fasting         preparation      1
# 1020  fasting       hash function      0
# 1017  fasting  infectious disease      0
# 1019  fasting             purpose      0
#
#                  concept         property  label
# 1598  management science       lewis acid      0
# 260   management science          journal      1
# 1599  management science        cell line      0
# 1600  management science  african country      0
# 1601  management science         facility      0
# 1597  management science        appliance      0
#
#               concept          property  label
# 594  electron density    funding source      0
# 592  electron density         organelle      0
# 593  electron density            animal      0
# 57   electron density  plasma parameter      1
# 595  electron density             drink      0
# 596  electron density         equipment      0
#
#            concept         property  label
# 209   conservation            topic      1
# 1356  conservation  natural process      0
# 1354  conservation        pollutant      0
# 1353  conservation          amenity      0
# 1352  conservation         organism      0
# 1355  conservation            topic      0
#
#          concept           property  label
# 257   coercivity  magnetic property      1
# 1585  coercivity       light source      0
# 1582  coercivity    eating disorder      0
# 1586  coercivity      vegetable oil      0
# 1583  coercivity           industry      0
# 1584  coercivity           composer      0
#
#     concept        property  label
# 316   armor          liquid      0
# 313   armor        additive      0
# 1     armor            item      1
# 314   armor       treatment      0
# 312   armor    neuropeptide      0
# 315   armor  funding source      0
#
#            concept             property  label
# 494  mashed potato       disturbed area      0
# 492  mashed potato           ingredient      0
# 495  mashed potato  antioxidizing agent      0
# 496  mashed potato        essential oil      0
# 37   mashed potato                 food      1
# 493  mashed potato           medication      0
#
#       concept                      property  label
# 1305  porsche  addiction treatment approach      0
# 199   porsche                         brand      1
# 1302  porsche                          game      0
# 1306  porsche             regulatory agency      0
# 1304  porsche                   information      0
# 1303  porsche                        sensor      0
#
#         concept                   property  label
# 1002  mediation                  vegetable      0
# 1006  mediation                      asset      0
# 1004  mediation                     injury      0
# 1005  mediation               lean protein      0
# 1003  mediation               light source      0
# 139   mediation  dispute resolution method      1
#
#      concept              property  label
# 1083  loader                  bird      0
# 1086  loader               surface      0
# 1082  loader            regulation      0
# 1085  loader  electrical appliance      0
# 155   loader             equipment      1
# 1084  loader                defect      0
#
#      concept                      property  label
# 1345  photon            musicianship skill      0
# 1343  photon                      province      0
# 1344  photon                          role      0
# 1342  photon                         issue      0
# 207   photon                      particle      1
# 1346  photon  addiction treatment approach      0
#
#     concept     property  label
# 781  dosage        nsaid      0
# 777  dosage    character      0
# 778  dosage   medication      0
# 779  dosage  third party      0
# 94   dosage       factor      1
# 780  dosage      setting      0
#
#      concept                           property  label
# 182   stereo                               item      1
# 1218  stereo                            surface      0
# 1219  stereo                     bronchodilator      0
# 1217  stereo  serious gastrointestinal toxicity      0
# 1220  stereo                             injury      0
# 1221  stereo                          substrate      0
#
#       concept    property  label
# 336  template  amino acid      0
# 333  template  identifier      0
# 334  template   substrate      0
# 5    template     feature      1
# 332  template     prophet      0
# 335  template    festival      0
#
#           concept             property  label
# 1260  part number  synthetic elastomer      0
# 190   part number          information      1
# 1259  part number          alkyl group      0
# ...
# 1565  gasification                    pyrethroid      0
# 253   gasification                    technology      1
# 1563  gasification  addiction treatment approach      0
# 1564  gasification                         genre      0
# 1566  gasification                         drink      0
#
#         concept                           property  label
# 590  ulceration                  patient care unit      0
# 588  ulceration               limited circumstance      0
# 591  ulceration                         regulation      0
# 587  ulceration                   serial interface      0
# 589  ulceration                       tree service      0
# 56   ulceration  serious gastrointestinal toxicity      1
#
#      concept            property  label
# 1744      5s              factor      0
# 1743      5s        light source      0
# 1746      5s          technology      0
# 292       5s                tool      1
# 1742      5s  infectious disease      0
# 1745      5s    serial interface      0
#
#      concept              property  label
# 884  rhubarb                 nsaid      0
# 886  rhubarb              activity      0
# 882  rhubarb               network      0
# 883  rhubarb        sleep disorder      0
# 115  rhubarb             vegetable      1
# 885  rhubarb  limited circumstance      0
#
#          concept                    property  label
# 786  child s age  international organization      0
# 784  child s age                      artist      0
# 95   child s age                      factor      1
# 782  child s age                     vitamin      0
# 785  child s age                    property      0
# 783  child s age              modern comfort      0
#
#         concept          property  label
# 983  asparagine            defect      0
# 982  asparagine  operating system      0
# 984  asparagine          resource      0
# 135  asparagine        amino acid      1
# 986  asparagine            artist      0
# 985  asparagine              city      0
#
#            concept      property  label
# 1389  canned goods       pattern      0
# 1390  canned goods      property      0
# 1387  canned goods  alkali metal      0
# 1388  canned goods         genre      0
# 216   canned goods          item      1
# 1391  canned goods        effect      0
#
#     concept      property  label
# 836   dubai         sugar      0
# 105   dubai          city      1
# 835   dubai         topic      0
# 834   dubai  lean protein      0
# 833   dubai         brand      0
# 832   dubai     equipment      0
#
#       concept        property  label
# 310  goldfish          method      0
# 311  goldfish        industry      0
# 307  goldfish  market dynamic      0
# 0    goldfish            fish      1
# 309  goldfish            cell      0
# 308  goldfish            bird      0
#
#       concept       property  label
# 224   mannose          sugar      1
# 1427  mannose   neuropeptide      0
# 1428  mannose   health issue      0
# 1430  mannose        prophet      0
# 1431  mannose  medium player      0
# 1429  mannose    information      0
#
#      concept            property  label
# 1437  osprey           accessory      0
# 1439  osprey               sugar      0
# 1440  osprey            property      0
# 1441  osprey               skill      0
# 226   osprey                bird      1
# 1438  osprey  autoimmune disease      0
#
#                    concept                      property  label
# 708  support group meeting                       purpose      0
# 709  support group meeting                       service      0
# 707  support group meeting                       vehicle      0
# 711  support group meeting                      additive      0
# 80   support group meeting  addiction treatment approach      1
# 710  support group meeting                          game      0
#
#         concept         property  label
# 749  polyphenol      information      0
# 748  polyphenol      preparation      0
# 751  polyphenol   bronchodilator      0
# 88   polyphenol         compound      1
# 747  polyphenol         material      0
# 750  polyphenol  african country      0
#
#          concept             property  label
# 474  bae systems              service      0
# 33   bae systems              company      1
# 473  bae systems        essential oil      0
# 476  bae systems  heavy cleaning duty      0
# 472  bae systems                brand      0
# 475  bae systems              keyword      0
#
#        concept                      property  label
# 1544  marriott                     treatment      0
# 1545  marriott                     organelle      0
# 1542  marriott  low molecular weight heparin      0
# 1543  marriott                    technology      0
# 249   marriott                       company      1
# 1546  marriott                 mobile device      0
#
#      concept                 property  label
# 1209  matrix                    video      0
# 1210  matrix     limited circumstance      0
# 247   matrix                    topic      1
# 1207  matrix  manipulating identifier      0
# 1211  matrix                 database      0
# 180   matrix                     film      1
# 1208  matrix               pyrethroid      0
#
#               concept                property  label
# 937  maintenance cost       combustion engine      0
# 940  maintenance cost                    role      0
# 938  maintenance cost     antioxidizing agent      0
# 939  maintenance cost  transcription enhancer      0
# 941  maintenance cost                 company      0
# 126  maintenance cost                    cost      1
#
#      concept          property  label
# 165     palm     vegetable oil      1
# 1135    palm     memory medium      0
# 1132    palm  natural disaster      0
# 1134    palm       soy product      0
# 1133    palm    bronchodilator      0
# 1136    palm            animal      0
#
#         concept          property  label
# 730  permethrin           mineral      0
# 729  permethrin            effect      0
# 84   permethrin        pyrethroid      1
# 731  permethrin  operating system      0
# 728  permethrin            injury      0
# 727  permethrin          document      0
#
#       concept          property  label
# 1760  gauteng  plasma parameter      0
# 295   gauteng          province      1
# 1757  gauteng            sensor      0
# 1758  gauteng         pollutant      0
# 1761  gauteng         parameter      0
# 1759  gauteng       preparation      0
#
#               concept             property  label
# 1158  royal caribbean          credit card      0
# 1160  royal caribbean            appliance      0
# 1157  royal caribbean        medium player      0
# 170   royal caribbean          cruise line      1
# 1159  royal caribbean                genre      0
# 1161  royal caribbean  antioxidizing agent      0
#
#     concept   property  label
# 511   bagel     device      0
# 507   bagel      video      0
# 508   bagel       herb      0
# 40    bagel       food      1
# 509   bagel    company      0
# 510   bagel  parameter      0
#
#       concept        property  label
# 1223  cartier        document      0
# 1222  cartier  market dynamic      0
# 1226  cartier          method      0
# 183   cartier           brand      1
# 1225  cartier         emotion      0
# 1224  cartier       perennial      0
#
#        concept          property  label
# 1525  stroller     plant hormone      0
# 1522  stroller  personal expense      0
# 244   stroller              item      1
# 1526  stroller         stimulant      0
# 1524  stroller             sport      0
# 1523  stroller       application      0
#
#                concept         property  label
# 1360  laundry facility  chelating agent      0
# 1359  laundry facility         material      0
# 210   laundry facility          amenity      1
# 1358  laundry facility            sugar      0
# 1357  laundry facility    vegetable oil      0
# 1361  laundry facility      insecticide      0
#
#          concept                property  label
# 378  metal alloy                particle      0
# 377  metal alloy                    fish      0
# 379  metal alloy  transcription enhancer      0
# 381  metal alloy            complication      0
# 380  metal alloy        optical property      0
# 14   metal alloy                material      1
#
#         concept            property  label
# 109  distortion              effect      1
# 853  distortion     eating disorder      0
# 854  distortion  infectious disease      0
# 855  distortion        complication      0
# 856  distortion      market dynamic      0
# 852  distortion  alpha hydroxy acid      0
#
#         concept                      property  label
# 1377  first aid                      database      0
# 214   first aid                         skill      1
# 1380  first aid                       allergy      0
# 1381  first aid                          bird      0
# 1378  first aid  low molecular weight heparin      0
# 1379  first aid                      cytokine      0
#
#          concept                      property  label
# 1011  enoxaparin                     condition      0
# 1009  enoxaparin                         brand      0
# 1008  enoxaparin                          task      0
# 1007  enoxaparin                      compound      0
# 140   enoxaparin  low molecular weight heparin      1
# 1010  enoxaparin               eating disorder      0
#
#                   concept          property  label
# 59   windows media player     medium player      1
# 603  windows media player         treatment      0
# 606  windows media player          resource      0
# 605  windows media player              tool      0
# 602  windows media player  personal expense      0
# 604  windows media player           service      0
#
#               concept                       property  label
# 1732  glass substrate                          breed      0
# 1734  glass substrate                  vegetable oil      0
# 1733  glass substrate                 modern comfort      0
# 1736  glass substrate  personal protective equipment      0
# 1735  glass substrate                       activity      0
# 290   glass substrate                      substrate      1
#
#           concept                           property  label
# 1029  muscle cell                           exercise      0
# 1030  muscle cell  serious gastrointestinal toxicity      0
# 1028  muscle cell            manipulating identifier      0
# 144   muscle cell                               cell      1
# 1031  muscle cell                   personal expense      0
# 1027  muscle cell                               item      0
#
#                  concept                    property  label
# 259   particulate matter                   pollutant      1
# 1595  particulate matter               plant hormone      0
# 1592  particulate matter  polyunsaturated fatty acid      0
# 1593  particulate matter              funding source      0
# 1596  particulate matter                    exercise      0
# 1594  particulate matter                     journal      0
#
#            concept     property  label
# 1752  hospital bed        virus      0
# 1756  hospital bed   pyrethroid      0
# 1754  hospital bed  preparation      0
# 1753  hospital bed        brand      0
# 1755  hospital bed     document      0
# 294   hospital bed         item      1
#
#                concept                       property  label
# 8    immunosuppression                         factor      1
# 350  immunosuppression                      substrate      0
# 348  immunosuppression  personal protective equipment      0
# 349  immunosuppression                        amenity      0
# 351  immunosuppression                  plant hormone      0
# 347  immunosuppression                     ingredient      0
#
#        concept                      property  label
# 1099  overhead                      material      0
# 158   overhead                          cost      1
# 1101  overhead  addiction treatment approach      0
# 1098  overhead              operating system      0
# 1097  overhead                   alkyl group      0
# 1100  overhead           antioxidizing agent      0
#
#           concept           property  label
# 262   angry birds               game      1
# 1604  angry birds  regulatory agency      0
# 1602  angry birds        application      0
# 1603  angry birds            vehicle      0
# 1606  angry birds               herb      0
# 1605  angry birds       neuropeptide      0
#
#      concept       property  label
# 1628   boxer       activity      0
# 1631   boxer  essential oil      0
# 1630   boxer       facility      0
# 1627   boxer           herb      0
# 267    boxer          breed      1
# 1629   boxer         artist      0
#
#      concept            property  label
# 1802  motrin          pyrethroid      0
# 1806  motrin       vegetable oil      0
# 1805  motrin  musicianship skill      0
# 304   motrin               nsaid      1
# 1803  motrin            database      0
# 1804  motrin          lewis acid      0
#
#          concept         property  label
# 790  recognition          solvent      0
# 789  recognition            sport      0
# 787  recognition     neuropeptide      0
# 791  recognition             film      0
# 788  recognition  chelating agent      0
# 96   recognition           factor      1
#
#      concept              property  label
# 1108   pitch     magnetic property      0
# 1111   pitch               mineral      0
# 1107   pitch  electrical appliance      0
# 160    pitch             parameter      1
# 1109   pitch      personal expense      0
# 1110   pitch                animal      0
#
#      concept             property  label
# 1297    dkny              symptom      0
# 1299    dkny            substrate      0
# 198     dkny                brand      1
# 1301    dkny  antioxidizing agent      0
# 1300    dkny              emotion      0
# 1298    dkny  synthetic elastomer      0
#
#       concept           property  label
# 724  roadside            mineral      0
# 722  roadside          bacterium      0
# 83   roadside     disturbed area      1
# 723  roadside               herb      0
# 726  roadside  regulatory agency      0
# 725  roadside      mobile device      0
#
#                             concept            property  label
# 275   vasoactive intestinal peptide        neuropeptide      1
# 1669  vasoactive intestinal peptide        distribution      0
# 1667  vasoactive intestinal peptide  musicianship skill      0
# 1671  vasoactive intestinal peptide            beverage      0
# 1668  vasoactive intestinal peptide          body fluid      0
# 1670  vasoactive intestinal peptide               nsaid      0
#
#               concept           property  label
# 461  single use glove          bacterium      0
# 457  single use glove  patient care unit      0
# 30   single use glove   suitable utensil      1
# 458  single use glove          incentive      0
# 459  single use glove      vegetable oil      0
# 460  single use glove             factor      0
#
#            concept                      property  label
# 700  halfway house                         topic      0
# 78   halfway house  addiction treatment approach      1
# 697  halfway house                        effect      0
# 698  halfway house                       product      0
# 699  halfway house                      compound      0
# 701  halfway house                         organ      0
#
#         concept            property  label
# 1155  malathion                part      0
# 1154  malathion             company      0
# 1152  malathion            software      0
# 169   malathion         insecticide      1
# 1156  malathion  alpha hydroxy acid      0
# 1153  malathion      bronchodilator      0
#
#     concept       property  label
# 524     eel         liquid      0
# 525     eel   light source      0
# 522     eel       exercise      0
# 523     eel        feature      0
# 43      eel           fish      1
# 526     eel  antihistamine      0
#
#         concept          property  label
# 235   albuterol    bronchodilator      1
# 1483  albuterol         cell line      0
# 1485  albuterol            artist      0
# 1486  albuterol           network      0
# 1484  albuterol  a-list celebrity      0
# 1482  albuterol      coated metal      0
#
#               concept    property  label
# 1672  golgi apparatus       state      0
# 276   golgi apparatus   organelle      1
# 1673  golgi apparatus        cost      0
# 1674  golgi apparatus       video      0
# 1676  golgi apparatus  lewis acid      0
# 1675  golgi apparatus        band      0

# %%
train_df.dtypes

# %%
def generate_negative_data(data_df, num_neg_pair=1):
    
    data_df.reset_index(drop=True, inplace=True)
    
    #print ('data_df.index :',data_df.index)
        
    negative_data = []
    
    concept_list = data_df['concept'].unique()

    for concept in concept_list:
        
        negative_data_for_concept = []

        positive_data = data_df[data_df["concept"] == concept]
        #positive_data_index = data_df[data_df["concept"] == concept].index
        positive_data_index = np.array(positive_data.index)
        num_positive_data = len(positive_data_index)

        rest_df = data_df.drop(positive_data_index)
        rest_df.reset_index(drop=True, inplace=True)
        rest_df_idx = rest_df.index
        
        pos_or_negative = np.random.choice(['neg_concept', 'neg_property'], size=len(positive_data_index))
        
        num_neg_concept = Counter(pos_or_negative).get('neg_concept')
        num_neg_property = Counter(pos_or_negative).get('neg_property')
                
        print ('\n')
        print ('--' * 50 )
        print ('Concept :', concept)
        print ('len(positive_data):', len(positive_data))
        print ('num_neg_concept :',  num_neg_concept)
        print ('num_neg_property :', num_neg_property)
        print ('postitive_data_index :', positive_data_index)
        print ('\npositive_data:')
        print (positive_data)
        
        neg_concept_data = []
        neg_property_data = []
        
        
        # indexes of the records for which concept will be corrupted.
        if num_neg_concept is not None:
            
            neg_concept_record_idx = np.random.choice(positive_data_index, size=num_neg_concept)
            neg_concept = rest_df.sample(n = num_neg_pair * num_neg_concept)['concept'].to_numpy()
            neg_concept_split = np.split(neg_concept, len(neg_concept_record_idx))
            
            print ('\nneg_concepts')
            print (neg_concept)
            
            for array, idx in zip(neg_concept_split, neg_concept_record_idx):
                neg_concept_data.extend([(con, positive_data.loc[idx]['property'], 0) for con in array])                
        else:
            print ('num_neg_concept in None')
            neg_concept_record_idx = []
        
        print ('Negative concept for true property')
        print (neg_concept_data)

                
        if num_neg_property is not None:
            
            # indexes of the records for which property will be corrupted.
            #neg_property_record_idx = np.array([idx for idx in positive_data_index if idx not in neg_concept_record_idx])
            
            neg_property = rest_df.sample(n=num_neg_pair * num_neg_property)['property'].to_list()
            print ('\nneg_property :', neg_property)
            
            neg_property_data.extend([(concept, neg_prop, 0) for neg_prop in neg_property])
            
        print ('Negative Property data for true Concept :')
        print (neg_property_data)
            
        negative_data_for_concept.extend(neg_concept_data)
        negative_data_for_concept.extend(neg_property_data)
        
        print ('\nNumber of Negative Data For Concept :', len(negative_data_for_concept))
        print ('negative_data_for_concept:')
        print (negative_data_for_concept)
        
        negative_data.append(negative_data_for_concept)
        

    negative_data_df = pd.concat([pd.DataFrame(data, columns=['concept', 'property', 'label']) \
                                  for data in negative_data], ignore_index=True)
    
    
    all_data = pd.concat([data_df, negative_data_df], ignore_index=True)
    
    all_data = all_data.sample(frac=1)
    all_data.drop_duplicates(inplace=True)
    
    print ('\nFinished Generating Data For One Set')
    print ('len(all_data) :', len(all_data))
    
    return all_data

# %%
print ('#' * 50)
print ('Generating Negative Train Data')

# %%
print ('\n Training Data')

# %%
pos_neg_train_df = generate_negative_data(train_df, num_neg_pair=num_neg_pair)
pos_neg_train_df.to_csv('data/65k_train_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Train Record Before Negative Data:', len(train_df))
print ('Train Record After Negative Data:', len(pos_neg_train_df))

# %%
print ('#' * 50)
print ('Generating Negative Valid Data')
print ('\n Validation Data')
pos_neg_val_df = generate_negative_data(valid_df, num_neg_pair=num_neg_pair)
pos_neg_val_df.to_csv('data/65k_valid_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Validation Record Before Negative Data:', len(valid_df))
print ('Validation Record After Negative Data:', len(pos_neg_val_df))

# %%
print ('#' * 50)
print ('Generating Negative Test Data')

print ('\n Test Data')
pos_neg_test_df = generate_negative_data(test_df, num_neg_pair=num_neg_pair)
pos_neg_test_df.to_csv('data/65k_test_ms_concept_graph.tsv', sep='\t', index=None, header=None)

# %%
print ()
print ('#' * 5)
print ('Test Record Before Negative Data:', len(test_df))
print ('Test Record After Negative Data:', len(pos_neg_test_df))
